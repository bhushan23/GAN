# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets
from torchvision import transforms
import torchvision
import os
import numpy as np
import matplotlib.pyplot as plt
import torchvision.utils as tutils
import imageio
import pickle
import copy
from PIL import Image

# %%
# Options being used 
batch_size = 100
imgDim = 28
path = './genImg/'
showPlot = False
savePlot = True
num_epochs = 200
IS_CUDA = False

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                     std=(0.5, 0.5, 0.5))])

# %%
# MNIST dataset
dataset = datasets.MNIST(root='../../data',
                         train=True,
                         transform=transform,
                         download=True)
# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

# %%
# Helper routines
if torch.cuda.is_available():
    IS_CUDA = True
    
def var(x):
    if IS_CUDA:
        x = x.cuda()
    return Variable(x)

def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
    
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

def generate_animation(root, epoch, name):
    images = []
    for e in range(epoch):
        img_name = root+'/image_'+str(e)+'.png'
        images.append(imageio.imread(img_name))
    imageio.mimsave(root+ '/' + name +'.gif', images, fps=5)

def save_image(pic, path):
    grid = torchvision.utils.make_grid(pic, nrow=8, padding=2)
    ndarr = grid.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
    im = Image.fromarray(ndarr)
    im.save(path)

class LossModule: 
    def __init__(self, numberOfGens = 1):
        self.D_loss = []
        self.G_loss = []
        self.Many_G_loss = [[]] * (numberOfGens+1)

    def insertDiscriminatorLoss(self, lossVal):
        self.D_loss.append(lossVal)
    
    def insertGeneratorLoss(self, lossVal):
        self.G_loss.append(lossVal)
    
    def insertGeneratorList(self, lossList):
        for i in range(0, len(lossList)):
            self.Many_G_loss[i].append(lossList[i])
        
    def getDiscriminatorLoss(self):
        return self.D_loss
    
    def getGeneratorLoss(self):
        return self.G_loss
    
    def getGeneratorsList(self):
        return self.Many_G_loss
    
    def drawLossPlot(self, showPlot = False, savePlot = True, label = "Vanilla GAN Loss", genList = False):
        plt.xlabel('Iterations')
        plt.ylabel('Loss')
        plt.title(label)
        if genList == True:
            i = 0
            for each in self.Many_G_loss:
                i = i + 1
                plt.plot(self.G_loss, label='Generator Loss {}'.format(i))
        else:
            plt.plot(self.G_loss, label='Generator Loss')
        plt.plot(self.D_loss, label='Discriminator Loss')
        legend = plt.legend(loc='upper right', shadow=True)

        if showPlot:
            plt.show()
        if savePlot:
            plt.savefig(loc+'Loss_Plot_Vanilla_GAN_'+str(num_epochs)+'.png')

# %%
# Network
'''
Generator = nn.Sequential(
        nn.Linear(Generator_input, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 784),
        nn.Tanh())

Discriminator = nn.Sequential(
        nn.Linear(784, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256,1),
        nn.Sigmoid())
'''
Discriminator = nn.Sequential(
            nn.Linear(784, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,1),
            nn.Sigmoid())

Generator_input = 64

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Linear(Generator_input, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Sequential(nn.Linear(256, 784), nn.Tanh())
        self.lR = nn.LeakyReLU(0.2)
            
    def forward(self, x):
        x = self.fc1(x)
        x = self.lR(x)
        x = self.fc2(x)
        x = self.lR(x)
        return self.fc3(x)


#Gen = Generator()
Generators = []
GOptimizers = []
NumberOfGenerators = 3
for i in range(NumberOfGenerators):
    #Generators.append(copy.deepcopy(Generator))
    Generators.append(Generator())

if IS_CUDA:
    Discriminator.cuda()
    for each in Generators:
        each.cuda()

# %%
lossManager = LossModule(numberOfGens = NumberOfGenerators)
lossCriterion = nn.BCELoss()
D_opt = torch.optim.Adam(Discriminator.parameters(), lr = 0.0001)
#G_opt = torch.optim.Adam(Gen.parameters(), lr = 0.0001)
GOptimizers = []
for each in Generators:
    GOptimizers.append(torch.optim.Adam(each.parameters(), lr = 0.0001))

fixed_x = var(torch.randn(batch_size, Generator_input))

GeneratorLoss = []
def backPropGenerator(index, GeneratorLoss):
    Generators[index].zero_grad()
    GeneratorLoss[index].backward()
    GOptimizers[index].step()

# %%
# load model by loading from best one
outputImages = []
def train(BestPerformingGenerator, num_epochs = 10, d_iter = 1):
    for epoch in range(num_epochs):
        lossList = [0.0] * NumberOfGenerators
        for data in data_loader:
            image, _  = data
            image = var(image.view(image.size(0),  -1))
            
            # Train Discriminator
            #for k in range(0, d_iter):
            Z_noise = var(torch.randn(batch_size, Generator_input))
            for each in Generators:
                D_real = Discriminator(image)
                # For Log(1 - D(G(Z)))
                #print Z_noise.shape
                #print type(Gen)
                G_fake = each(Z_noise) #Generators[BestPerformingGenerator](Z_noise)
                #print G_fake.shape
                D_fake = Discriminator(G_fake)

                # Calculate Discriminator Loss
                D_real_loss = lossCriterion(D_real, var(torch.ones(batch_size, 1)))
                D_fake_loss = lossCriterion(D_fake, var(torch.zeros(batch_size, 1)))
                D_loss = D_real_loss + D_fake_loss

                # Backprop Discriminator
                Discriminator.zero_grad()
                D_loss.backward()
                D_opt.step()
                #print 'Discriminator Loop for: {}: {}'.format(i, D_loss.data[0])
   
            # Find best performing Generator
            i = 0
            GeneratorLoss = []
            Z_noise = var(torch.randn(batch_size, Generator_input))
            for each, each_opt in zip(Generators, GOptimizers):
                
                G_fake = each(Z_noise)
                #print G_fake1.shape
                #print type(each)
                D_fake = Discriminator(G_fake)
                # Compute Generator Loss
                G_loss = lossCriterion(D_fake, var(torch.ones(batch_size, 1)))
                GeneratorLoss.append(G_loss)
                lossList[i] += (float(G_loss.data[0]))
                i = i + 1
                Discriminator.zero_grad()
                each.zero_grad()
                G_loss.backward()
                each_opt.step()
                #backPropGenerator(i, GeneratorLoss)
                #print 'Generator Loop for: {}: {}'.format(i, G_loss.data[0])
            
            #print lossList
            #print type(lossList[0])
        BestPerformingGenerator = lossList.index(min(lossList)) # earlier was min
        print lossList
        for i in range(0, NumberOfGenerators):
            if i != BestPerformingGenerator:
                prev = Generators[i]
                Generators[i] = Generator()
                Generators[i].load_state_dict(Generators[BestPerformingGenerator].state_dict())
                GOptimizers[i] = torch.optim.Adam(Generators[i].parameters(), lr = 0.0001)
                GOptimizers[i].load_state_dict(GOptimizers[BestPerformingGenerator].state_dict())
                #Generators[i] = copy.deepcopy(Generators[BestPerformingGenerator])
                #GOptimizers[i] = torch.optim.Adam(Generators[i].parameters(), lr = 0.0001)
                #copy.deepcopy(GOptimizers[BestPerformingGenerator])
                if Generators[i] == prev:
                    print 'SAME'

        #print epoch
        print BestPerformingGenerator
        print 'Epoch [{}/{}], Discriminator {:.4f}, Best Generator[{}] {:.4f}'.format(epoch+1, num_epochs, D_loss.data[0], BestPerformingGenerator, GeneratorLoss[BestPerformingGenerator].data[0])
        lossManager.insertDiscriminatorLoss(D_loss.data[0])
        lossManager.insertGeneratorLoss(G_loss.data[0])
        #lossManager.insertGeneratorList(lossList)
        pic = Generators[BestPerformingGenerator](var(torch.randn(batch_size, Generator_input)))
        pic = pic.view(pic.size(0), 1, 28, 28) 
        pic = denorm(pic.data)
        outputImages.append(pic)
        #torchvision.utils.save_image(pic, path+'image_{}.png'.format(epoch))
        save_image(pic, path+'image_{}.png'.format(epoch))

# %%
num_epochs = 200
BestPerformingGenerator = train(0, num_epochs)
# Out:
# [2563.5823445916176, 2590.6408252716064, 2675.7307454943657]
# 0
# Epoch [1/200], Discriminator 0.0103, Best Generator[0] 6.2311
# [4438.47302877903, 4438.47302877903, 4438.47302877903]
# 0
# Epoch [2/200], Discriminator 0.0955, Best Generator[0] 8.8616
# [3062.6449506282806, 3062.6449506282806, 3062.6449506282806]
# 0
# Epoch [3/200], Discriminator 0.0898, Best Generator[0] 2.9682
# [3246.0185520648956, 3246.0185520648956, 3246.0185520648956]
# 0
# Epoch [4/200], Discriminator 0.0063, Best Generator[0] 6.5320
# [3857.3359014987946, 3857.3359014987946, 3857.3359014987946]
# 0
# Epoch [5/200], Discriminator 0.0108, Best Generator[0] 7.4586
# [3882.219033718109, 3882.219033718109, 3882.219033718109]
# 0
# Epoch [6/200], Discriminator 0.0413, Best Generator[0] 4.4876
# [4603.47660279274, 4603.47660279274, 4603.47660279274]
# 0
# Epoch [7/200], Discriminator 0.0526, Best Generator[0] 10.4166
# [4736.138650894165, 4736.138650894165, 4736.138650894165]
# 0
# Epoch [8/200], Discriminator 0.0229, Best Generator[0] 10.7887
# [4440.03591799736, 4440.03591799736, 4440.03591799736]
# 0
# Epoch [9/200], Discriminator 0.0615, Best Generator[0] 6.1036
# [4456.570333480835, 4456.570333480835, 4456.570333480835]
# 0
# Epoch [10/200], Discriminator 0.0023, Best Generator[0] 7.7983
# [4876.032710790634, 4876.032710790634, 4876.032710790634]
# 0
# Epoch [11/200], Discriminator 0.0047, Best Generator[0] 13.8623
# [5645.100929260254, 5645.100929260254, 5645.100929260254]
# 0
# Epoch [12/200], Discriminator 0.0098, Best Generator[0] 9.8383
# [5060.4146864414215, 5060.4146864414215, 5060.4146864414215]
# 0
# Epoch [13/200], Discriminator 0.0243, Best Generator[0] 9.1565
# [5069.804003953934, 5069.804003953934, 5069.804003953934]
# 0
# Epoch [14/200], Discriminator 0.0466, Best Generator[0] 7.9998
# [5088.983724832535, 5088.983724832535, 5088.983724832535]
# 0
# Epoch [15/200], Discriminator 0.0146, Best Generator[0] 10.5370
# [4747.40562081337, 4747.40562081337, 4747.40562081337]
# 0
# Epoch [16/200], Discriminator 0.0788, Best Generator[0] 4.4934
# [4730.867084741592, 4730.867084741592, 4730.867084741592]
# 0
# Epoch [17/200], Discriminator 0.0451, Best Generator[0] 6.0831
# [4616.070227384567, 4616.070227384567, 4616.070227384567]
# 0
# Epoch [18/200], Discriminator 0.1369, Best Generator[0] 7.7715
# [4612.525497198105, 4612.525497198105, 4612.525497198105]
# 0
# Epoch [19/200], Discriminator 0.0313, Best Generator[0] 7.8254
# [4285.006549835205, 4285.006549835205, 4285.006549835205]
# 0
# Epoch [20/200], Discriminator 0.1028, Best Generator[0] 7.4793
# [4092.5764303207397, 4092.5764303207397, 4092.5764303207397]
# 0
# Epoch [21/200], Discriminator 0.0670, Best Generator[0] 6.2855
# [3595.3213987350464, 3595.3213987350464, 3595.3213987350464]
# 0
# Epoch [22/200], Discriminator 0.0885, Best Generator[0] 7.3262
# [3269.1227366924286, 3269.1227366924286, 3269.1227366924286]
# 0
# Epoch [23/200], Discriminator 0.3568, Best Generator[0] 4.7936
# [2866.768254995346, 2866.768254995346, 2866.768254995346]
# 0
# Epoch [24/200], Discriminator 0.2187, Best Generator[0] 5.4632
# [2808.128901720047, 2808.128901720047, 2808.128901720047]
# 0
# Epoch [25/200], Discriminator 0.1532, Best Generator[0] 5.2061
# [2657.189945578575, 2657.189945578575, 2657.189945578575]
# 0
# Epoch [26/200], Discriminator 0.1688, Best Generator[0] 4.1975
# [2684.415125966072, 2684.415125966072, 2684.415125966072]
# 0
# Epoch [27/200], Discriminator 0.0862, Best Generator[0] 4.7657
# [2638.64427113533, 2638.64427113533, 2638.64427113533]
# 0
# Epoch [28/200], Discriminator 0.1670, Best Generator[0] 3.9002
# [2495.5214500427246, 2495.5214500427246, 2495.5214500427246]
# 0
# Epoch [29/200], Discriminator 0.1896, Best Generator[0] 3.4991
# [2427.2423080205917, 2427.2423080205917, 2427.2423080205917]
# 0
# Epoch [30/200], Discriminator 0.3210, Best Generator[0] 2.7294
# [2299.2271592617035, 2299.2271592617035, 2299.2271592617035]
# 0
# Epoch [31/200], Discriminator 0.2028, Best Generator[0] 1.6883
# [2407.462786078453, 2407.462786078453, 2407.462786078453]
# 0
# Epoch [32/200], Discriminator 0.2354, Best Generator[0] 3.5491
# [2502.1760276556015, 2502.1760276556015, 2502.1760276556015]
# 0
# Epoch [33/200], Discriminator 0.1901, Best Generator[0] 4.4790
# [2761.177066087723, 2761.177066087723, 2761.177066087723]
# 0
# Epoch [34/200], Discriminator 0.0588, Best Generator[0] 7.3841
# [2721.7420486211777, 2721.7420486211777, 2721.7420486211777]
# 0
# Epoch [35/200], Discriminator 0.1888, Best Generator[0] 4.6398
# [2644.8687546253204, 2644.8687546253204, 2644.8687546253204]
# 0
# Epoch [36/200], Discriminator 0.2629, Best Generator[0] 4.8862
# [2834.27056992054, 2834.27056992054, 2834.27056992054]
# 0
# Epoch [37/200], Discriminator 0.2450, Best Generator[0] 3.6426
# [2726.9277098178864, 2726.9277098178864, 2726.9277098178864]
# 0
# Epoch [38/200], Discriminator 0.1319, Best Generator[0] 5.1265
# [2745.83926987648, 2745.83926987648, 2745.83926987648]
# 0
# Epoch [39/200], Discriminator 0.1835, Best Generator[0] 5.8630
# [2831.1682163476944, 2831.1682163476944, 2831.1682163476944]
# 0
# Epoch [40/200], Discriminator 0.1298, Best Generator[0] 7.7042
# [3037.376274585724, 3037.376274585724, 3037.376274585724]
# 0
# Epoch [41/200], Discriminator 0.0832, Best Generator[0] 5.9116
# [4586.080271959305, 4586.080271959305, 4586.080271959305]
# 0
# Epoch [42/200], Discriminator 0.0722, Best Generator[0] 8.6434
# [5710.961111903191, 5710.961111903191, 5710.961111903191]
# 0
# Epoch [43/200], Discriminator 0.0018, Best Generator[0] 13.3876
# [11263.481722831726, 11263.481722831726, 11263.481722831726]
# 0
# Epoch [44/200], Discriminator 0.0759, Best Generator[0] 12.8738
# [5676.239005327225, 5676.239005327225, 5676.239005327225]
# 0
# Epoch [45/200], Discriminator 0.0413, Best Generator[0] 8.1635
# [3511.8476388454437, 3511.8476388454437, 3511.8476388454437]
# 0
# Epoch [46/200], Discriminator 0.1414, Best Generator[0] 5.8682
# [2707.5609208345413, 2707.5609208345413, 2707.5609208345413]
# 0
# Epoch [47/200], Discriminator 0.2381, Best Generator[0] 4.5840
# [2418.248904824257, 2418.248904824257, 2418.248904824257]
# 0
# Epoch [48/200], Discriminator 0.3667, Best Generator[0] 3.6326
# [2256.9313719272614, 2256.9313719272614, 2256.9313719272614]
# 0
# Epoch [49/200], Discriminator 0.3023, Best Generator[0] 2.5735
# [2098.110147833824, 2098.110147833824, 2098.110147833824]
# 0
# Epoch [50/200], Discriminator 0.3646, Best Generator[0] 3.7783
# [2043.6312626600266, 2043.6312626600266, 2043.6312626600266]
# 0
# Epoch [51/200], Discriminator 0.2861, Best Generator[0] 2.7934
# [1992.768603682518, 1992.768603682518, 1992.768603682518]
# 0
# Epoch [52/200], Discriminator 0.2348, Best Generator[0] 3.3032
# [1916.4209234714508, 1916.4209234714508, 1916.4209234714508]
# 0
# Epoch [53/200], Discriminator 0.2406, Best Generator[0] 2.9357
# [1872.4968974590302, 1872.4968974590302, 1872.4968974590302]
# 0
# Epoch [54/200], Discriminator 0.2758, Best Generator[0] 3.5240
# [1856.8030623197556, 1856.8030623197556, 1856.8030623197556]
# 0
# Epoch [55/200], Discriminator 0.3347, Best Generator[0] 2.6942
# [1802.910794377327, 1802.910794377327, 1802.910794377327]
# 0
# Epoch [56/200], Discriminator 0.2945, Best Generator[0] 2.4059
# [1787.2295615673065, 1787.2295615673065, 1787.2295615673065]
# 0
# Epoch [57/200], Discriminator 0.2544, Best Generator[0] 4.3401
# [1715.1502891778946, 1715.1502891778946, 1715.1502891778946]
# 0
# Epoch [58/200], Discriminator 0.2646, Best Generator[0] 3.1953
# [1712.1396751403809, 1712.1396751403809, 1712.1396751403809]
# 0
# Epoch [59/200], Discriminator 0.2299, Best Generator[0] 4.5109
# [1786.7679294347763, 1786.7679294347763, 1786.7679294347763]
# 0
# Epoch [60/200], Discriminator 0.4445, Best Generator[0] 2.7002
# [1848.5387810468674, 1848.5387810468674, 1848.5387810468674]
# 0
# Epoch [61/200], Discriminator 0.3173, Best Generator[0] 2.5905
# [1991.280352115631, 1991.280352115631, 1991.280352115631]
# 0
# Epoch [62/200], Discriminator 0.2322, Best Generator[0] 2.7364
# [2291.353075504303, 2291.353075504303, 2291.353075504303]
# 0
# Epoch [63/200], Discriminator 0.1883, Best Generator[0] 3.1310
# [3019.8296772241592, 3019.8296772241592, 3019.8296772241592]
# 0
# Epoch [64/200], Discriminator 0.1146, Best Generator[0] 5.6391
# [4152.480391740799, 4152.480391740799, 4152.480391740799]
# 0
# Epoch [65/200], Discriminator 0.0305, Best Generator[0] 11.7813
# [4541.994795560837, 4541.994795560837, 4541.994795560837]
# 0
# Epoch [66/200], Discriminator 0.0180, Best Generator[0] 8.6448
# [5830.731929302216, 5830.731929302216, 5830.731929302216]
# 0
# Epoch [67/200], Discriminator 0.0133, Best Generator[0] 10.8694
# [7452.425925254822, 7452.425925254822, 7452.425925254822]
# 0
# Epoch [68/200], Discriminator 0.0104, Best Generator[0] 9.3645
# [7044.130705833435, 7044.130705833435, 7044.130705833435]
# 0
# Epoch [69/200], Discriminator 0.0630, Best Generator[0] 8.1365
# [4211.797527313232, 4211.797527313232, 4211.797527313232]
# 0
# Epoch [70/200], Discriminator 0.1025, Best Generator[0] 5.9521
# [3181.77863740921, 3181.77863740921, 3181.77863740921]
# 0
# Epoch [71/200], Discriminator 0.2656, Best Generator[0] 4.0642
# [2462.972255706787, 2462.972255706787, 2462.972255706787]
# 0
# Epoch [72/200], Discriminator 0.1667, Best Generator[0] 3.1760
# [2290.9241831302643, 2290.9241831302643, 2290.9241831302643]
# 0
# Epoch [73/200], Discriminator 0.2600, Best Generator[0] 3.1373
# [2127.9062093496323, 2127.9062093496323, 2127.9062093496323]
# 0
# Epoch [74/200], Discriminator 0.2648, Best Generator[0] 4.0423
# [1994.0754792690277, 1994.0754792690277, 1994.0754792690277]
# 0
# Epoch [75/200], Discriminator 0.3399, Best Generator[0] 2.7619
# [1937.4998828172684, 1937.4998828172684, 1937.4998828172684]
# 0
# Epoch [76/200], Discriminator 0.3307, Best Generator[0] 3.4462
# [1867.3949711322784, 1867.3949711322784, 1867.3949711322784]
# 0
# Epoch [77/200], Discriminator 0.3149, Best Generator[0] 2.9388
# [1852.7203599214554, 1852.7203599214554, 1852.7203599214554]
# 0
# Epoch [78/200], Discriminator 0.3136, Best Generator[0] 1.7525
# [1781.7643843889236, 1781.7643843889236, 1781.7643843889236]
# 0
# Epoch [79/200], Discriminator 0.5664, Best Generator[0] 2.4254
# [1748.625621676445, 1748.625621676445, 1748.625621676445]
# 0
# Epoch [80/200], Discriminator 0.1942, Best Generator[0] 3.2627
# [1687.0918871164322, 1687.0918871164322, 1687.0918871164322]
# 0
# Epoch [81/200], Discriminator 0.3884, Best Generator[0] 3.1774
# [1658.967691898346, 1658.967691898346, 1658.967691898346]
# 0
# Epoch [82/200], Discriminator 0.2861, Best Generator[0] 2.1623
# [1640.1890350580215, 1640.1890350580215, 1640.1890350580215]
# 0
# Epoch [83/200], Discriminator 0.3904, Best Generator[0] 2.8196
# [1628.8000704050064, 1628.8000704050064, 1628.8000704050064]
# 0
# Epoch [84/200], Discriminator 0.3937, Best Generator[0] 3.0935
# [1636.0192083120346, 1636.0192083120346, 1636.0192083120346]
# 0
# Epoch [85/200], Discriminator 0.4405, Best Generator[0] 1.7430
# [1643.1619832515717, 1643.1619832515717, 1643.1619832515717]
# 0
# Epoch [86/200], Discriminator 0.5042, Best Generator[0] 1.7147
# [1653.5319979190826, 1653.5319979190826, 1653.5319979190826]
# 0
# Epoch [87/200], Discriminator 0.2990, Best Generator[0] 2.8451
# [1615.8174823522568, 1615.8174823522568, 1615.8174823522568]
# 0
# Epoch [88/200], Discriminator 0.2686, Best Generator[0] 2.8376
# [1606.8785469532013, 1606.8785469532013, 1606.8785469532013]
# 0
# Epoch [89/200], Discriminator 0.3220, Best Generator[0] 2.6998
# [1585.9494471549988, 1585.9494471549988, 1585.9494471549988]
# 0
# Epoch [90/200], Discriminator 0.2195, Best Generator[0] 2.7945
# [1575.9021708965302, 1575.9021708965302, 1575.9021708965302]
# 0
# Epoch [91/200], Discriminator 0.4494, Best Generator[0] 2.4004
# [1572.661500096321, 1572.661500096321, 1572.661500096321]
# 0
# Epoch [92/200], Discriminator 0.5036, Best Generator[0] 3.4334
# [1563.416983127594, 1563.416983127594, 1563.416983127594]
# 0
# Epoch [93/200], Discriminator 0.2787, Best Generator[0] 2.5956
# [1564.883319735527, 1564.883319735527, 1564.883319735527]
# 0
# Epoch [94/200], Discriminator 0.3745, Best Generator[0] 3.0529
# [1536.4767407178879, 1536.4767407178879, 1536.4767407178879]
# 0
# Epoch [95/200], Discriminator 0.4370, Best Generator[0] 2.6788
# [1540.5881311893463, 1540.5881311893463, 1540.5881311893463]
# 0
# Epoch [96/200], Discriminator 0.4152, Best Generator[0] 2.7745
# [1582.7127199172974, 1582.7127199172974, 1582.7127199172974]
# 0
# Epoch [97/200], Discriminator 0.3439, Best Generator[0] 2.3260
# [1537.4979186058044, 1537.4979186058044, 1537.4979186058044]
# 0
# Epoch [98/200], Discriminator 0.3268, Best Generator[0] 2.1205
# [1537.6629339456558, 1537.6629339456558, 1537.6629339456558]
# 0
# Epoch [99/200], Discriminator 0.3775, Best Generator[0] 2.2163
# [1531.0004127025604, 1531.0004127025604, 1531.0004127025604]
# 0
# Epoch [100/200], Discriminator 0.3335, Best Generator[0] 1.8602
# [1530.3394691944122, 1530.3394691944122, 1530.3394691944122]
# 0
# Epoch [101/200], Discriminator 0.3931, Best Generator[0] 2.1330
# [1515.2303339242935, 1515.2303339242935, 1515.2303339242935]
# 0
# Epoch [102/200], Discriminator 0.3218, Best Generator[0] 2.0572
# [1505.210440993309, 1505.210440993309, 1505.210440993309]
# 0
# Epoch [103/200], Discriminator 0.3226, Best Generator[0] 2.3682
# [1513.6124901771545, 1513.6124901771545, 1513.6124901771545]
# 0
# Epoch [104/200], Discriminator 0.2925, Best Generator[0] 3.0437
# [1510.737468123436, 1510.737468123436, 1510.737468123436]
# 0
# Epoch [105/200], Discriminator 0.3860, Best Generator[0] 2.3599
# [1506.5723276138306, 1506.5723276138306, 1506.5723276138306]
# 0
# Epoch [106/200], Discriminator 0.4145, Best Generator[0] 2.4991
# [1498.6438102722168, 1498.6438102722168, 1498.6438102722168]
# 0
# Epoch [107/200], Discriminator 0.3251, Best Generator[0] 1.9954
# [1505.9469405412674, 1505.9469405412674, 1505.9469405412674]
# 0
# Epoch [108/200], Discriminator 0.4492, Best Generator[0] 2.3556
# [1517.938994884491, 1517.938994884491, 1517.938994884491]
# 0
# Epoch [109/200], Discriminator 0.2681, Best Generator[0] 2.3264
# [1492.8062545061111, 1492.8062545061111, 1492.8062545061111]
# 0
# Epoch [110/200], Discriminator 0.3531, Best Generator[0] 3.3077
# [1488.3917630910873, 1488.3917630910873, 1488.3917630910873]
# 0
# Epoch [111/200], Discriminator 0.3398, Best Generator[0] 2.7621
# [1491.282680630684, 1491.282680630684, 1491.282680630684]
# 0
# Epoch [112/200], Discriminator 0.3691, Best Generator[0] 1.9717
# [1483.6873080730438, 1483.6873080730438, 1483.6873080730438]
# 0
# Epoch [113/200], Discriminator 0.2948, Best Generator[0] 2.5223
# [1501.2167621850967, 1501.2167621850967, 1501.2167621850967]
# 0
# Epoch [114/200], Discriminator 0.3990, Best Generator[0] 2.1260
# [1496.5884269475937, 1496.5884269475937, 1496.5884269475937]
# 0
# Epoch [115/200], Discriminator 0.3190, Best Generator[0] 1.6235
# [1495.69468998909, 1495.69468998909, 1495.69468998909]
# 0
# Epoch [116/200], Discriminator 0.3122, Best Generator[0] 2.9867
# [1495.521798491478, 1495.521798491478, 1495.521798491478]
# 0
# Epoch [117/200], Discriminator 0.3622, Best Generator[0] 2.6218
# [1505.4443554878235, 1505.4443554878235, 1505.4443554878235]
# 0
# Epoch [118/200], Discriminator 0.4113, Best Generator[0] 2.2670
# [1483.8137165307999, 1483.8137165307999, 1483.8137165307999]
# 0
# Epoch [119/200], Discriminator 0.2682, Best Generator[0] 2.2323
# [1485.7718988656998, 1485.7718988656998, 1485.7718988656998]
# 0
# Epoch [120/200], Discriminator 0.5311, Best Generator[0] 2.5921
# [1486.8155845403671, 1486.8155845403671, 1486.8155845403671]
# 0
# Epoch [121/200], Discriminator 0.2601, Best Generator[0] 2.3065
# [1506.7554783821106, 1506.7554783821106, 1506.7554783821106]
# 0
# Epoch [122/200], Discriminator 0.3332, Best Generator[0] 2.5283
# [1503.4746421575546, 1503.4746421575546, 1503.4746421575546]
# 0
# Epoch [123/200], Discriminator 0.4297, Best Generator[0] 2.0400
# [1469.3420078754425, 1469.3420078754425, 1469.3420078754425]
# 0
# Epoch [124/200], Discriminator 0.3738, Best Generator[0] 2.4756
# [1490.093570113182, 1490.093570113182, 1490.093570113182]
# 0
# Epoch [125/200], Discriminator 0.3603, Best Generator[0] 2.1260
# [1489.942135334015, 1489.942135334015, 1489.942135334015]
# 0
# Epoch [126/200], Discriminator 0.3243, Best Generator[0] 3.1054
# [1482.8331679105759, 1482.8331679105759, 1482.8331679105759]
# 0
# Epoch [127/200], Discriminator 0.3780, Best Generator[0] 2.0298
# [1492.284378528595, 1492.284378528595, 1492.284378528595]
# 0
# Epoch [128/200], Discriminator 0.3279, Best Generator[0] 2.2915
# [1494.956328511238, 1494.956328511238, 1494.956328511238]
# 0
# Epoch [129/200], Discriminator 0.2717, Best Generator[0] 2.1209
# [1489.008251786232, 1489.008251786232, 1489.008251786232]
# 0
# Epoch [130/200], Discriminator 0.3185, Best Generator[0] 2.2027
# [1487.6267141103745, 1487.6267141103745, 1487.6267141103745]
# 0
# Epoch [131/200], Discriminator 0.3326, Best Generator[0] 2.1400
# [1491.6176968812943, 1491.6176968812943, 1491.6176968812943]
# 0
# Epoch [132/200], Discriminator 0.4264, Best Generator[0] 3.4362
# [1468.23550593853, 1468.23550593853, 1468.23550593853]
# 0
# Epoch [133/200], Discriminator 0.3370, Best Generator[0] 2.9645
# [1476.955097436905, 1476.955097436905, 1476.955097436905]
# 0
# Epoch [134/200], Discriminator 0.3913, Best Generator[0] 1.8982
# [1503.019893169403, 1503.019893169403, 1503.019893169403]
# 0
# Epoch [135/200], Discriminator 0.4622, Best Generator[0] 2.3547
# [1509.671247959137, 1509.671247959137, 1509.671247959137]
# 0
# Epoch [136/200], Discriminator 0.3876, Best Generator[0] 2.1217
# [1470.916883468628, 1470.916883468628, 1470.916883468628]
# 0
# Epoch [137/200], Discriminator 0.4172, Best Generator[0] 1.9505
# [1472.4047133922577, 1472.4047133922577, 1472.4047133922577]
# 0
# Epoch [138/200], Discriminator 0.4848, Best Generator[0] 2.0596
# [1463.7648839950562, 1463.7648839950562, 1463.7648839950562]
# 0
# Epoch [139/200], Discriminator 0.4182, Best Generator[0] 2.2106
# [1481.7168319225311, 1481.7168319225311, 1481.7168319225311]
# 0
# Epoch [140/200], Discriminator 0.3813, Best Generator[0] 2.7301
# [1477.2018529176712, 1477.2018529176712, 1477.2018529176712]
# 0
# Epoch [141/200], Discriminator 0.3544, Best Generator[0] 2.2630
# [1478.6306657791138, 1478.6306657791138, 1478.6306657791138]
# 0
# Epoch [142/200], Discriminator 0.2851, Best Generator[0] 2.3193
# [1480.9551488161087, 1480.9551488161087, 1480.9551488161087]
# 0
# Epoch [143/200], Discriminator 0.3965, Best Generator[0] 2.7890
# [1482.9463868141174, 1482.9463868141174, 1482.9463868141174]
# 0
# Epoch [144/200], Discriminator 0.4925, Best Generator[0] 2.3047
# [1463.194102525711, 1463.194102525711, 1463.194102525711]
# 0
# Epoch [145/200], Discriminator 0.3533, Best Generator[0] 2.3173
# [1467.7045731544495, 1467.7045731544495, 1467.7045731544495]
# 0
# Epoch [146/200], Discriminator 0.3826, Best Generator[0] 1.8107
# [1475.9747350215912, 1475.9747350215912, 1475.9747350215912]
# 0
# Epoch [147/200], Discriminator 0.2738, Best Generator[0] 2.5449
# [1494.3140486478806, 1494.3140486478806, 1494.3140486478806]
# 0
# Epoch [148/200], Discriminator 0.4041, Best Generator[0] 2.1337
# [1466.5583137273788, 1466.5583137273788, 1466.5583137273788]
# 0
# Epoch [149/200], Discriminator 0.3728, Best Generator[0] 2.2195
# [1495.0065261125565, 1495.0065261125565, 1495.0065261125565]
# 0
# Epoch [150/200], Discriminator 0.3219, Best Generator[0] 2.4930
# [1466.3782405853271, 1466.3782405853271, 1466.3782405853271]
# 0
# Epoch [151/200], Discriminator 0.3817, Best Generator[0] 2.5544
# [1471.795268535614, 1471.795268535614, 1471.795268535614]
# 0
# Epoch [152/200], Discriminator 0.4376, Best Generator[0] 2.5841
# [1469.2994470596313, 1469.2994470596313, 1469.2994470596313]
# 0
# Epoch [153/200], Discriminator 0.4632, Best Generator[0] 2.1815
# [1476.9000787734985, 1476.9000787734985, 1476.9000787734985]
# 0
# Epoch [154/200], Discriminator 0.4252, Best Generator[0] 1.8348
# [1472.4665418863297, 1472.4665418863297, 1472.4665418863297]
# 0
# Epoch [155/200], Discriminator 0.4189, Best Generator[0] 2.7509
# [1468.102301955223, 1468.102301955223, 1468.102301955223]
# 0
# Epoch [156/200], Discriminator 0.2857, Best Generator[0] 2.3991
# [1473.4051107168198, 1473.4051107168198, 1473.4051107168198]
# 0
# Epoch [157/200], Discriminator 0.3670, Best Generator[0] 2.1090
# [1484.2984808683395, 1484.2984808683395, 1484.2984808683395]
# 0
# Epoch [158/200], Discriminator 0.3942, Best Generator[0] 1.8846
# [1482.7485736608505, 1482.7485736608505, 1482.7485736608505]
# 0
# Epoch [159/200], Discriminator 0.3378, Best Generator[0] 2.2000
# [1506.6464052200317, 1506.6464052200317, 1506.6464052200317]
# 0
# Epoch [160/200], Discriminator 0.2963, Best Generator[0] 2.5296
# [1478.5756472349167, 1478.5756472349167, 1478.5756472349167]
# 0
# Epoch [161/200], Discriminator 0.2597, Best Generator[0] 2.7957
# [1486.4032123088837, 1486.4032123088837, 1486.4032123088837]
# 0
# Epoch [162/200], Discriminator 0.4821, Best Generator[0] 2.6564
# [1480.5956894159317, 1480.5956894159317, 1480.5956894159317]
# 0
# Epoch [163/200], Discriminator 0.3052, Best Generator[0] 2.3690
# [1477.1571959257126, 1477.1571959257126, 1477.1571959257126]
# 0
# Epoch [164/200], Discriminator 0.3993, Best Generator[0] 2.3808
# [1478.4448169469833, 1478.4448169469833, 1478.4448169469833]
# 0
# Epoch [165/200], Discriminator 0.3109, Best Generator[0] 2.5348
# [1484.906662940979, 1484.906662940979, 1484.906662940979]
# 0
# Epoch [166/200], Discriminator 0.3867, Best Generator[0] 2.0808
# [1480.413025379181, 1480.413025379181, 1480.413025379181]
# 0
# Epoch [167/200], Discriminator 0.3822, Best Generator[0] 2.0515
# [1484.2416807413101, 1484.2416807413101, 1484.2416807413101]
# 0
# Epoch [168/200], Discriminator 0.4442, Best Generator[0] 2.9770
# [1494.0994292497635, 1494.0994292497635, 1494.0994292497635]
# 0
# Epoch [169/200], Discriminator 0.3303, Best Generator[0] 2.0362
# [1494.8878328800201, 1494.8878328800201, 1494.8878328800201]
# 0
# Epoch [170/200], Discriminator 0.4122, Best Generator[0] 2.2294
# [1489.3283774852753, 1489.3283774852753, 1489.3283774852753]
# 0
# Epoch [171/200], Discriminator 0.3671, Best Generator[0] 3.0465
# [1485.790195941925, 1485.790195941925, 1485.790195941925]
# 0
# Epoch [172/200], Discriminator 0.4028, Best Generator[0] 3.6384
# [1477.6019834280014, 1477.6019834280014, 1477.6019834280014]
# 0
# Epoch [173/200], Discriminator 0.4316, Best Generator[0] 2.0885
# [1482.6529233455658, 1482.6529233455658, 1482.6529233455658]
# 0
# Epoch [174/200], Discriminator 0.2717, Best Generator[0] 2.7179
# [1486.0105769634247, 1486.0105769634247, 1486.0105769634247]
# 0
# Epoch [175/200], Discriminator 0.3489, Best Generator[0] 2.4440
# [1480.0377434492111, 1480.0377434492111, 1480.0377434492111]
# 0
# Epoch [176/200], Discriminator 0.5942, Best Generator[0] 2.3182
# [1488.8437505960464, 1488.8437505960464, 1488.8437505960464]
# 0
# Epoch [177/200], Discriminator 0.4812, Best Generator[0] 2.5846
# [1491.2034882307053, 1491.2034882307053, 1491.2034882307053]
# 0
# Epoch [178/200], Discriminator 0.2636, Best Generator[0] 2.5318
# [1493.6746512651443, 1493.6746512651443, 1493.6746512651443]
# 0
# Epoch [179/200], Discriminator 0.2956, Best Generator[0] 2.2577
# [1482.3307881355286, 1482.3307881355286, 1482.3307881355286]
# 0
# Epoch [180/200], Discriminator 0.4014, Best Generator[0] 2.3414
# [1482.579672574997, 1482.579672574997, 1482.579672574997]
# 0
# Epoch [181/200], Discriminator 0.4059, Best Generator[0] 2.6156
# [1482.9973833560944, 1482.9973833560944, 1482.9973833560944]
# 0
# Epoch [182/200], Discriminator 0.4595, Best Generator[0] 2.6018
# [1479.7449924945831, 1479.7449924945831, 1479.7449924945831]
# 0
# Epoch [183/200], Discriminator 0.3140, Best Generator[0] 2.3886
# [1493.6685947179794, 1493.6685947179794, 1493.6685947179794]
# 0
# Epoch [184/200], Discriminator 0.2309, Best Generator[0] 2.9180
# [1488.1940509080887, 1488.1940509080887, 1488.1940509080887]
# 0
# Epoch [185/200], Discriminator 0.3116, Best Generator[0] 2.5356
# [1484.2077382802963, 1484.2077382802963, 1484.2077382802963]
# 0
# Epoch [186/200], Discriminator 0.4210, Best Generator[0] 2.2655
# [1513.387161374092, 1513.387161374092, 1513.387161374092]
# 0
# Epoch [187/200], Discriminator 0.5132, Best Generator[0] 2.1737
# [1476.1989130973816, 1476.1989130973816, 1476.1989130973816]
# 0
# Epoch [188/200], Discriminator 0.4048, Best Generator[0] 2.1885
# [1479.0328060388565, 1479.0328060388565, 1479.0328060388565]
# 0
# Epoch [189/200], Discriminator 0.4335, Best Generator[0] 2.5202
# [1497.9453213214874, 1497.9453213214874, 1497.9453213214874]
# 0
# Epoch [190/200], Discriminator 0.4126, Best Generator[0] 2.6042
# [1479.3940881490707, 1479.3940881490707, 1479.3940881490707]
# 0
# Epoch [191/200], Discriminator 0.4095, Best Generator[0] 1.8932
# [1491.4491393566132, 1491.4491393566132, 1491.4491393566132]
# 0
# Epoch [192/200], Discriminator 0.3252, Best Generator[0] 2.1233
# [1495.5849025249481, 1495.5849025249481, 1495.5849025249481]
# 0
# Epoch [193/200], Discriminator 0.3010, Best Generator[0] 2.3044
# [1491.5596623420715, 1491.5596623420715, 1491.5596623420715]
# 0
# Epoch [194/200], Discriminator 0.4292, Best Generator[0] 2.2457
# [1489.4770070314407, 1489.4770070314407, 1489.4770070314407]
# 0
# Epoch [195/200], Discriminator 0.3557, Best Generator[0] 2.9295
# [1492.7983130216599, 1492.7983130216599, 1492.7983130216599]
# 0
# Epoch [196/200], Discriminator 0.3114, Best Generator[0] 2.4953
# [1486.177483677864, 1486.177483677864, 1486.177483677864]
# 0
# Epoch [197/200], Discriminator 0.3488, Best Generator[0] 2.4005
# [1494.0555415153503, 1494.0555415153503, 1494.0555415153503]
# 0
# Epoch [198/200], Discriminator 0.3430, Best Generator[0] 2.2913
# [1494.7223054170609, 1494.7223054170609, 1494.7223054170609]
# 0
# Epoch [199/200], Discriminator 0.4342, Best Generator[0] 2.6782
# [1500.0888661146164, 1500.0888661146164, 1500.0888661146164]
# 0
# Epoch [200/200], Discriminator 0.3169, Best Generator[0] 2.5167

# %%
# Plot the Loss for Generator and Discriminator
lossManager.drawLossPlot(showPlot = True, savePlot = False)

# %%
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Min Same Noise Co-Operative GAN')
plt.plot(lossManager.getGeneratorLoss(), label='Generator Loss')
plt.plot(lossManager.getDiscriminatorLoss(), label='Discriminator Loss')
legend = plt.legend(loc='upper right', shadow=True)
#plt.show()
plt.savefig('Loss_Plot_Vanilla_Min_Same_Noise_Co-Operative_GAN_'+str(num_epochs)+'.png')
#lossManager.drawLossPlot(showPlot = True, savePlot = False, genList = True)

# %%
#lossL = lossManager.getGeneratorsList()

# %%
# Generate GIF
generate_animation(path, num_epochs, 'Min_Multiple_Gens')

# %%
# Save the model
torch.save(Generators[BestPerformingGenerator].state_dict(), './Generator.pkl')
torch.save(Discriminator.state_dict(), './Discriminator.pkl')
pickle.dump(lossManager, open( "LossManager.pkl", "wb" ))

# %%
# Load Loss Manager for viewing data of 200 iterations
#lossManagerTrained = pickle.load(open( "200Iteration/LossManager.pkl", "rb" ))

# %%
#drawLossPlot(lossManagerTrained.getGeneratorLoss(), lossManagerTrained.getDiscriminatorLoss(), showPlot = False, savePlot = True, loc = "200Iteration")
#drawLossPlot(lossManagerTrained.getGeneratorLoss(), lossManagerTrained.getDiscriminatorLoss(), showPlot = True, savePlot = False, loc = "200Iteration")

# %%
# Load model for debugging and testing
#Generator.load_state_dict(torch.load('Generator200.pkl'))
#Discriminator.load_state_dict(torch.load('Discriminator200.pkl'))
