# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets
from torchvision import transforms
import torchvision
import os
import numpy as np
import matplotlib.pyplot as plt
import torchvision.utils as tutils
import imageio
import pickle
import copy
from PIL import Image

# %%
# Options being used 
batch_size = 100
imgDim = 28
path = './genImg/'
showPlot = False
savePlot = True
num_epochs = 200
IS_CUDA = False

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                     std=(0.5, 0.5, 0.5))])

# %%
# MNIST dataset
dataset = datasets.MNIST(root='../../data',
                         train=True,
                         transform=transform,
                         download=True)
# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

# %%
# Helper routines
if torch.cuda.is_available():
    IS_CUDA = True
    
def var(x):
    if IS_CUDA:
        x = x.cuda()
    return Variable(x)

def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
    
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

def generate_animation(root, epoch, name):
    images = []
    for e in range(epoch):
        img_name = root+'/image_'+str(e)+'.png'
        images.append(imageio.imread(img_name))
    imageio.mimsave(root+ '/' + name +'.gif', images, fps=5)

def save_image(pic, path):
    grid = torchvision.utils.make_grid(pic, nrow=8, padding=2)
    ndarr = grid.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
    im = Image.fromarray(ndarr)
    im.save(path)

class LossModule: 
    def __init__(self, numberOfGens = 1):
        self.D_loss = []
        self.G_loss = []
        self.Many_G_loss = [[]] * (numberOfGens+1)

    def insertDiscriminatorLoss(self, lossVal):
        self.D_loss.append(lossVal)
    
    def insertGeneratorLoss(self, lossVal):
        self.G_loss.append(lossVal)
    
    def insertGeneratorList(self, lossList):
        for i in range(0, len(lossList)):
            self.Many_G_loss[i].append(lossList[i])
        
    def getDiscriminatorLoss(self):
        return self.D_loss
    
    def getGeneratorLoss(self):
        return self.G_loss
    
    def getGeneratorsList(self):
        return self.Many_G_loss
    
    def drawLossPlot(self, showPlot = False, savePlot = True, label = "Vanilla GAN Loss", genList = False):
        plt.xlabel('Iterations')
        plt.ylabel('Loss')
        plt.title(label)
        if genList == True:
            i = 0
            for each in self.Many_G_loss:
                i = i + 1
                plt.plot(self.G_loss, label='Generator Loss {}'.format(i))
        else:
            plt.plot(self.G_loss, label='Generator Loss')
        plt.plot(self.D_loss, label='Discriminator Loss')
        legend = plt.legend(loc='upper right', shadow=True)

        if showPlot:
            plt.show()
        if savePlot:
            plt.savefig(loc+'Loss_Plot_Vanilla_GAN_'+str(num_epochs)+'.png')

# %%
# Network
'''
Generator = nn.Sequential(
        nn.Linear(Generator_input, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 784),
        nn.Tanh())

Discriminator = nn.Sequential(
        nn.Linear(784, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256,1),
        nn.Sigmoid())
'''
Discriminator = nn.Sequential(
            nn.Linear(784, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,1),
            nn.Sigmoid())

Generator_input = 64

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Linear(Generator_input, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Sequential(nn.Linear(256, 784), nn.Tanh())
        self.lR = nn.LeakyReLU(0.2)
            
    def forward(self, x):
        x = self.fc1(x)
        x = self.lR(x)
        x = self.fc2(x)
        x = self.lR(x)
        return self.fc3(x)


#Gen = Generator()
Generators = []
GOptimizers = []
NumberOfGenerators = 3
for i in range(NumberOfGenerators):
    #Generators.append(copy.deepcopy(Generator))
    Generators.append(Generator())

if IS_CUDA:
    Discriminator.cuda()
    for each in Generators:
        each.cuda()

# %%
lossManager = LossModule(numberOfGens = NumberOfGenerators)
lossCriterion = nn.BCELoss()
D_opt = torch.optim.Adam(Discriminator.parameters(), lr = 0.0001)
#G_opt = torch.optim.Adam(Gen.parameters(), lr = 0.0001)
GOptimizers = []
for each in Generators:
    GOptimizers.append(torch.optim.Adam(each.parameters(), lr = 0.0001))

fixed_x = var(torch.randn(batch_size, Generator_input))

GeneratorLoss = []
def backPropGenerator(index, GeneratorLoss):
    Generators[index].zero_grad()
    GeneratorLoss[index].backward()
    GOptimizers[index].step()

# %%
# load model by loading from best one
outputImages = []
def train(BestPerformingGenerator, num_epochs = 10, d_iter = 1):
    for epoch in range(num_epochs):
        lossList = [0.0] * NumberOfGenerators
        for data in data_loader:
            image, _  = data
            image = var(image.view(image.size(0),  -1))
            
            # Train Discriminator
            #for k in range(0, d_iter):
            for each in Generators:
                D_real = Discriminator(image)
                # For Log(1 - D(G(Z)))
                Z_noise = var(torch.randn(batch_size, Generator_input))
                #print Z_noise.shape
                #print type(Gen)
                G_fake = each(Z_noise) #Generators[BestPerformingGenerator](Z_noise)
                #print G_fake.shape
                D_fake = Discriminator(G_fake)

                # Calculate Discriminator Loss
                D_real_loss = lossCriterion(D_real, var(torch.ones(batch_size, 1)))
                D_fake_loss = lossCriterion(D_fake, var(torch.zeros(batch_size, 1)))
                D_loss = D_real_loss + D_fake_loss

                # Backprop Discriminator
                Discriminator.zero_grad()
                D_loss.backward()
                D_opt.step()
                #print 'Discriminator Loop for: {}: {}'.format(i, D_loss.data[0])
   
            # Find best performing Generator
            i = 0
            GeneratorLoss = []
            for each, each_opt in zip(Generators, GOptimizers):
                Z_noise = var(torch.randn(batch_size, Generator_input))
                G_fake = each(Z_noise)
                #print G_fake1.shape
                #print type(each)
                D_fake = Discriminator(G_fake)
                # Compute Generator Loss
                G_loss = lossCriterion(D_fake, var(torch.ones(batch_size, 1)))
                GeneratorLoss.append(G_loss)
                lossList[i] += (float(G_loss.data[0]))
                i = i + 1
                Discriminator.zero_grad()
                each.zero_grad()
                G_loss.backward()
                each_opt.step()
                #backPropGenerator(i, GeneratorLoss)
                #print 'Generator Loop for: {}: {}'.format(i, G_loss.data[0])
            
            #print lossList
            #print type(lossList[0])
        BestPerformingGenerator = lossList.index(min(lossList)) # earlier was min
        print lossList
        for i in range(0, NumberOfGenerators):
            if i != BestPerformingGenerator:
                prev = Generators[i]
                Generators[i] = Generator()
                Generators[i].load_state_dict(Generators[BestPerformingGenerator].state_dict())
                GOptimizers[i] = torch.optim.Adam(Generators[i].parameters(), lr = 0.0001)
                GOptimizers[i].load_state_dict(GOptimizers[BestPerformingGenerator].state_dict())
                #Generators[i] = copy.deepcopy(Generators[BestPerformingGenerator])
                #GOptimizers[i] = torch.optim.Adam(Generators[i].parameters(), lr = 0.0001)
                #copy.deepcopy(GOptimizers[BestPerformingGenerator])
                if Generators[i] == prev:
                    print 'SAME'

        #print epoch
        print BestPerformingGenerator
        print 'Epoch [{}/{}], Discriminator {:.4f}, Best Generator[{}] {:.4f}'.format(epoch+1, num_epochs, D_loss.data[0], BestPerformingGenerator, GeneratorLoss[BestPerformingGenerator].data[0])
        lossManager.insertDiscriminatorLoss(D_loss.data[0])
        lossManager.insertGeneratorLoss(G_loss.data[0])
        #lossManager.insertGeneratorList(lossList)
        pic = Generators[BestPerformingGenerator](var(torch.randn(batch_size, Generator_input)))
        pic = pic.view(pic.size(0), 1, 28, 28) 
        pic = denorm(pic.data)
        outputImages.append(pic)
        #torchvision.utils.save_image(pic, path+'image_{}.png'.format(epoch))
        save_image(pic, path+'image_{}.png'.format(epoch))

# %%
num_epochs = 200
BestPerformingGenerator = train(0, num_epochs)
# Out:
# [4772.748440027237, 4777.693321943283, 4762.908188343048]
# 2
# Epoch [1/200], Discriminator 0.0640, Best Generator[2] 10.3057
# [3195.9473531246185, 3126.2720015645027, 3179.009796857834]
# 1
# Epoch [2/200], Discriminator 0.0804, Best Generator[1] 4.9012
# [3292.1212496459484, 3090.1039382219315, 2878.7860407829285]
# 2
# Epoch [3/200], Discriminator 0.1988, Best Generator[2] 2.6461
# [3104.3899459578097, 2921.7012179791927, 2652.786212205887]
# 2
# Epoch [4/200], Discriminator 1.0681, Best Generator[2] 12.9840
# [3056.0552723407745, 2962.8754999637604, 2964.0499498844147]
# 1
# Epoch [5/200], Discriminator 0.0501, Best Generator[1] 5.7670
# [4014.946118891239, 4086.704157590866, 3689.2438321113586]
# 2
# Epoch [6/200], Discriminator 0.0602, Best Generator[2] 4.4215
# [4128.571269869804, 3723.473100602627, 4098.520096540451]
# 1
# Epoch [7/200], Discriminator 0.1394, Best Generator[1] 5.3264
# [4367.0841808617115, 4629.6378254294395, 4207.059344410896]
# 2
# Epoch [8/200], Discriminator 0.0663, Best Generator[2] 5.4181
# [4679.289042066783, 4426.049044966698, 4685.76441526413]
# 1
# Epoch [9/200], Discriminator 0.1858, Best Generator[1] 5.4759
# [4503.44873175025, 4502.275732517242, 4204.630695104599]
# 2
# Epoch [10/200], Discriminator 0.2148, Best Generator[2] 4.0532
# [4395.0680693443865, 4629.390672832727, 4309.276325583458]
# 2
# Epoch [11/200], Discriminator 0.2999, Best Generator[2] 3.5236
# [4489.799716293812, 4577.953242778778, 4466.601322412491]
# 2
# Epoch [12/200], Discriminator 0.0523, Best Generator[2] 5.7259
# [4339.807496234775, 4358.5413972735405, 4725.512254834175]
# 0
# Epoch [13/200], Discriminator 0.0408, Best Generator[0] 6.1935
# [4380.1821638047695, 4357.092844218016, 4177.156866669655]
# 2
# Epoch [14/200], Discriminator 0.2970, Best Generator[2] 13.8344
# [4318.207320213318, 4175.621255874634, 4390.347482681274]
# 1
# Epoch [15/200], Discriminator 0.0674, Best Generator[1] 4.8274
# [4393.493300199509, 4440.080001831055, 4423.937124967575]
# 0
# Epoch [16/200], Discriminator 0.0895, Best Generator[0] 4.6785
# [5136.649715423584, 5062.557844161987, 5052.168746709824]
# 2
# Epoch [17/200], Discriminator 0.0347, Best Generator[2] 8.6587
# [4520.716050595045, 4500.512661457062, 4574.758023262024]
# 1
# Epoch [18/200], Discriminator 0.1931, Best Generator[1] 5.7667
# [4494.789243936539, 4470.44272506237, 4389.142643451691]
# 2
# Epoch [19/200], Discriminator 0.1648, Best Generator[2] 3.7175
# [4468.34830904007, 4367.539072751999, 4352.446116685867]
# 2
# Epoch [20/200], Discriminator 0.1715, Best Generator[2] 6.2698
# [4521.7682475447655, 4549.689249038696, 4467.067492008209]
# 2
# Epoch [21/200], Discriminator 0.2511, Best Generator[2] 3.9238
# [4039.540268301964, 3934.758895665407, 4022.699751973152]
# 1
# Epoch [22/200], Discriminator 0.2370, Best Generator[1] 3.8913
# [3824.1882877349854, 3851.9544739723206, 3931.734782218933]
# 0
# Epoch [23/200], Discriminator 0.1085, Best Generator[0] 4.1818
# [4132.401534080505, 4052.5002930164337, 4006.688247561455]
# 2
# Epoch [24/200], Discriminator 0.1613, Best Generator[2] 4.7852
# [3932.9899184703827, 3918.677113056183, 3962.7915217876434]
# 1
# Epoch [25/200], Discriminator 0.2720, Best Generator[1] 4.0608
# [3855.9290215969086, 3760.6155108213425, 3919.212414264679]
# 1
# Epoch [26/200], Discriminator 0.2351, Best Generator[1] 3.4909
# [3686.702904820442, 3746.0800454616547, 3586.80980861187]
# 2
# Epoch [27/200], Discriminator 0.2587, Best Generator[2] 3.5821
# [3486.236698627472, 3431.797490954399, 3474.4059042930603]
# 1
# Epoch [28/200], Discriminator 0.2489, Best Generator[1] 2.8442
# [3491.024625301361, 3582.5200085639954, 3523.5720200538635]
# 0
# Epoch [29/200], Discriminator 0.1331, Best Generator[0] 4.0154
# [3371.624200940132, 3290.9994151592255, 3370.900323152542]
# 1
# Epoch [30/200], Discriminator 0.3471, Best Generator[1] 5.7682
# [3121.0831953287125, 3174.612107396126, 3145.6426305770874]
# 0
# Epoch [31/200], Discriminator 0.3233, Best Generator[0] 4.6861
# [2780.321085214615, 2762.3156085014343, 2906.575782775879]
# 1
# Epoch [32/200], Discriminator 0.2415, Best Generator[1] 5.4844
# [2670.1091899871826, 2747.159548997879, 2714.1671011447906]
# 0
# Epoch [33/200], Discriminator 0.4248, Best Generator[0] 4.5813
# [2823.8259110450745, 2754.7862300872803, 2742.025588989258]
# 2
# Epoch [34/200], Discriminator 0.2638, Best Generator[2] 3.5712
# [2847.541195869446, 2698.2736899852753, 2665.0302169322968]
# 2
# Epoch [35/200], Discriminator 0.2184, Best Generator[2] 3.8782
# [2734.588186979294, 2641.9769982099533, 2624.415275335312]
# 2
# Epoch [36/200], Discriminator 0.2433, Best Generator[2] 4.1614
# [2443.49385035038, 2481.8734008073807, 2395.5849797725677]
# 2
# Epoch [37/200], Discriminator 0.4439, Best Generator[2] 3.0800
# [2333.4456508159637, 2411.660964369774, 2432.5604865550995]
# 0
# Epoch [38/200], Discriminator 0.2555, Best Generator[0] 3.8814
# [2418.4659110307693, 2226.214129984379, 2328.7988325357437]
# 1
# Epoch [39/200], Discriminator 0.3857, Best Generator[1] 2.8322
# [2166.9131186008453, 2288.637403011322, 2291.538046836853]
# 0
# Epoch [40/200], Discriminator 0.4049, Best Generator[0] 2.9484
# [2305.0687993764877, 2162.6194854974747, 2153.719803094864]
# 2
# Epoch [41/200], Discriminator 0.3732, Best Generator[2] 2.5631
# [2169.2665095329285, 2171.4943821430206, 2084.3540675640106]
# 2
# Epoch [42/200], Discriminator 0.3734, Best Generator[2] 2.6558
# [2194.3746951818466, 2156.9551194906235, 2140.9362310171127]
# 2
# Epoch [43/200], Discriminator 0.3611, Best Generator[2] 2.9724
# [2357.110249519348, 2356.0135917663574, 2440.3679226636887]
# 1
# Epoch [44/200], Discriminator 0.3356, Best Generator[1] 2.6236
# [2348.8086116313934, 2231.7258108854294, 2124.6881107091904]
# 2
# Epoch [45/200], Discriminator 0.3712, Best Generator[2] 3.8701
# [2269.920725107193, 2164.3359141349792, 2140.5649151802063]
# 2
# Epoch [46/200], Discriminator 0.2648, Best Generator[2] 5.3913
# [2014.5546770691872, 2159.100722670555, 2128.373883366585]
# 0
# Epoch [47/200], Discriminator 0.4829, Best Generator[0] 4.0059
# [2005.3135254383087, 2044.090057849884, 1941.5503115653992]
# 2
# Epoch [48/200], Discriminator 0.3801, Best Generator[2] 2.5050
# [2130.0982967615128, 1999.3652076721191, 2053.298861026764]
# 1
# Epoch [49/200], Discriminator 0.5194, Best Generator[1] 2.3073
# [2070.580454826355, 2022.5299189090729, 1960.131082892418]
# 2
# Epoch [50/200], Discriminator 0.3794, Best Generator[2] 1.8061
# [2005.927177786827, 2005.0927457809448, 1930.2085161209106]
# 2
# Epoch [51/200], Discriminator 0.4426, Best Generator[2] 3.8114
# [1923.3538091182709, 1909.6970885396004, 1903.910699725151]
# 2
# Epoch [52/200], Discriminator 0.3683, Best Generator[2] 1.9007
# [1932.321899652481, 1968.099860906601, 1904.3477302789688]
# 2
# Epoch [53/200], Discriminator 0.4562, Best Generator[2] 2.3607
# [1868.7459535598755, 1886.721870958805, 1924.215358376503]
# 0
# Epoch [54/200], Discriminator 0.3809, Best Generator[0] 1.6191
# [1916.5930372476578, 1845.697995185852, 1824.7010962963104]
# 2
# Epoch [55/200], Discriminator 0.2984, Best Generator[2] 3.1202
# [1810.10294175148, 1879.942104101181, 1815.9860697984695]
# 0
# Epoch [56/200], Discriminator 0.4331, Best Generator[0] 1.6368
# [1810.7613711357117, 1795.8576546907425, 1815.9152697324753]
# 1
# Epoch [57/200], Discriminator 0.4570, Best Generator[1] 2.1769
# [1796.2738600969315, 1852.099904179573, 1816.786288022995]
# 0
# Epoch [58/200], Discriminator 0.3721, Best Generator[0] 2.0180
# [1797.6830880641937, 1760.5368483066559, 1776.2518520355225]
# 1
# Epoch [59/200], Discriminator 0.2714, Best Generator[1] 4.0226
# [1736.9019565582275, 1743.557095527649, 1729.1296591758728]
# 2
# Epoch [60/200], Discriminator 0.2917, Best Generator[2] 2.2398
# [1778.5645183324814, 1775.43705368042, 1762.7348750829697]
# 2
# Epoch [61/200], Discriminator 0.3004, Best Generator[2] 2.9950
# [1799.573436498642, 1803.9463614225388, 1770.4959732294083]
# 2
# Epoch [62/200], Discriminator 0.4480, Best Generator[2] 1.8369
# [1752.711313009262, 1728.776104927063, 1732.638173699379]
# 1
# Epoch [63/200], Discriminator 0.3927, Best Generator[1] 2.9684
# [1736.0906530618668, 1795.8228944540024, 1757.199526309967]
# 0
# Epoch [64/200], Discriminator 0.2810, Best Generator[0] 2.7568
# [1763.9427987337112, 1763.1430225372314, 1760.6307797431946]
# 2
# Epoch [65/200], Discriminator 0.5117, Best Generator[2] 2.4990
# [1734.2180010080338, 1725.732306599617, 1710.2524244785309]
# 2
# Epoch [66/200], Discriminator 0.4002, Best Generator[2] 2.2545
# [1701.9625253677368, 1691.5319405794144, 1708.509171128273]
# 1
# Epoch [67/200], Discriminator 0.3706, Best Generator[1] 1.8089
# [1683.2455813884735, 1670.3875584602356, 1700.1615558862686]
# 1
# Epoch [68/200], Discriminator 0.4041, Best Generator[1] 2.9310
# [1683.2971708774567, 1675.68909907341, 1688.543756365776]
# 1
# Epoch [69/200], Discriminator 0.4101, Best Generator[1] 1.9962
# [1689.2509033679962, 1683.8778915405273, 1698.0269440412521]
# 1
# Epoch [70/200], Discriminator 0.3285, Best Generator[1] 2.7453
# [1654.3929883241653, 1643.265885233879, 1654.77701151371]
# 1
# Epoch [71/200], Discriminator 0.3372, Best Generator[1] 2.3765
# [1670.5218977928162, 1650.0409951210022, 1657.7624586820602]
# 1
# Epoch [72/200], Discriminator 0.2389, Best Generator[1] 2.1510
# [1637.194620013237, 1640.089968085289, 1638.8245128393173]
# 0
# Epoch [73/200], Discriminator 0.3430, Best Generator[0] 2.5074
# [1635.0485516786575, 1633.723737359047, 1645.789214372635]
# 1
# Epoch [74/200], Discriminator 0.2899, Best Generator[1] 2.5447
# [1636.600468993187, 1640.7658987045288, 1636.3968163728714]
# 2
# Epoch [75/200], Discriminator 0.3939, Best Generator[2] 2.1358
# [1666.40214073658, 1674.8664457798004, 1682.7488223314285]
# 0
# Epoch [76/200], Discriminator 0.3701, Best Generator[0] 2.6248
# [1701.1439086198807, 1698.7690991163254, 1692.3239144086838]
# 2
# Epoch [77/200], Discriminator 0.3395, Best Generator[2] 2.3726
# [1636.7118158340454, 1638.8456828594208, 1637.4428709745407]
# 0
# Epoch [78/200], Discriminator 0.3496, Best Generator[0] 2.0126
# [1617.0085793733597, 1609.6209999322891, 1616.8593440055847]
# 1
# Epoch [79/200], Discriminator 0.2773, Best Generator[1] 2.1228
# [1655.6863152980804, 1629.5947427749634, 1640.145405292511]
# 1
# Epoch [80/200], Discriminator 0.2346, Best Generator[1] 2.6442
# [1638.9771729707718, 1640.6170921325684, 1638.336993098259]
# 2
# Epoch [81/200], Discriminator 0.3188, Best Generator[2] 2.4107
# [1628.2219899892807, 1628.9630454778671, 1631.8401707410812]
# 0
# Epoch [82/200], Discriminator 0.3074, Best Generator[0] 3.9157
# [1629.7607403993607, 1635.7866986989975, 1632.0996651649475]
# 0
# Epoch [83/200], Discriminator 0.3655, Best Generator[0] 2.8227
# [1623.1413424015045, 1602.9525374174118, 1613.9467980861664]
# 1
# Epoch [84/200], Discriminator 0.3727, Best Generator[1] 2.6473
# [1643.1959108114243, 1635.1721779108047, 1635.5228768587112]
# 1
# Epoch [85/200], Discriminator 0.3739, Best Generator[1] 2.5258
# [1616.1803883314133, 1619.039236664772, 1598.0194927453995]
# 2
# Epoch [86/200], Discriminator 0.5131, Best Generator[2] 1.6257
# [1587.9977622032166, 1584.8627212047577, 1591.2913471460342]
# 1
# Epoch [87/200], Discriminator 0.3177, Best Generator[1] 3.0962
# [1658.847684621811, 1664.4050742387772, 1671.9935555458069]
# 0
# Epoch [88/200], Discriminator 0.3678, Best Generator[0] 2.0759
# [1657.2229001522064, 1643.6597295999527, 1644.1974909305573]
# 1
# Epoch [89/200], Discriminator 0.4309, Best Generator[1] 3.4879
# [1646.1285265684128, 1658.4307796955109, 1654.243197798729]
# 0
# Epoch [90/200], Discriminator 0.2970, Best Generator[0] 2.9027
# [1642.5520708560944, 1649.1025174856186, 1633.5263789892197]
# 2
# Epoch [91/200], Discriminator 0.3560, Best Generator[2] 1.8621
# [1601.8132671117783, 1601.4884444475174, 1610.5470851659775]
# 1
# Epoch [92/200], Discriminator 0.3112, Best Generator[1] 2.8442
# [1617.437569618225, 1614.187990307808, 1616.1315732002258]
# 1
# Epoch [93/200], Discriminator 0.4511, Best Generator[1] 2.0881
# [1640.7387182712555, 1640.1681323051453, 1654.384107351303]
# 1
# Epoch [94/200], Discriminator 0.2864, Best Generator[1] 2.4991
# [1592.6277142763138, 1593.2183011770248, 1595.3513318300247]
# 0
# Epoch [95/200], Discriminator 0.3233, Best Generator[0] 2.3499
# [1607.4872417449951, 1602.9985649585724, 1622.5829756259918]
# 1
# Epoch [96/200], Discriminator 0.4525, Best Generator[1] 2.8708
# [1602.1789016723633, 1600.3768589496613, 1602.4585319757462]
# 1
# Epoch [97/200], Discriminator 0.3759, Best Generator[1] 2.6694
# [1615.768089056015, 1601.8379219770432, 1611.9339631795883]
# 1
# Epoch [98/200], Discriminator 0.4247, Best Generator[1] 2.6141
# [1599.0653669834137, 1579.980723619461, 1592.2936444282532]
# 1
# Epoch [99/200], Discriminator 0.4117, Best Generator[1] 2.7539
# [1618.0492545366287, 1618.137619972229, 1615.9836233854294]
# 2
# Epoch [100/200], Discriminator 0.2928, Best Generator[2] 4.0627
# [1613.2421888113022, 1616.877251625061, 1606.7323050498962]
# 2
# Epoch [101/200], Discriminator 0.3207, Best Generator[2] 2.2710
# [1615.0481241941452, 1599.4000477790833, 1598.9270139932632]
# 2
# Epoch [102/200], Discriminator 0.5287, Best Generator[2] 1.8321
# [1559.8415316343307, 1570.7310577630997, 1554.7477123737335]
# 2
# Epoch [103/200], Discriminator 0.4578, Best Generator[2] 2.6709
# [1576.9867907762527, 1582.8479670286179, 1576.360453248024]
# 2
# Epoch [104/200], Discriminator 0.2956, Best Generator[2] 2.7475
# [1563.1863515377045, 1570.0059163570404, 1562.4481177330017]
# 2
# Epoch [105/200], Discriminator 0.4195, Best Generator[2] 2.0035
# [1576.7995582818985, 1578.2361723184586, 1581.1876872777939]
# 0
# Epoch [106/200], Discriminator 0.3178, Best Generator[0] 2.4624
# [1626.8781915903091, 1614.0242906808853, 1625.627988576889]
# 1
# Epoch [107/200], Discriminator 0.4311, Best Generator[1] 2.5546
# [1565.4467842578888, 1554.9477672576904, 1560.7336517572403]
# 1
# Epoch [108/200], Discriminator 0.3232, Best Generator[1] 2.4172
# [1570.679641842842, 1579.1001558303833, 1589.2980831861496]
# 0
# Epoch [109/200], Discriminator 0.4043, Best Generator[0] 2.7548
# [1559.8041605949402, 1548.3039200305939, 1550.384339928627]
# 1
# Epoch [110/200], Discriminator 0.3262, Best Generator[1] 2.4302
# [1518.8340474367142, 1512.866661787033, 1523.5733960866928]
# 1
# Epoch [111/200], Discriminator 0.3278, Best Generator[1] 2.5146
# [1499.5479559898376, 1509.5932282209396, 1504.7752912044525]
# 0
# Epoch [112/200], Discriminator 0.3389, Best Generator[0] 2.5446
# [1580.4189732074738, 1576.4369132518768, 1563.2054827213287]
# 2
# Epoch [113/200], Discriminator 0.4244, Best Generator[2] 2.2960
# [1549.900319814682, 1549.5228885412216, 1547.8127564191818]
# 2
# Epoch [114/200], Discriminator 0.4818, Best Generator[2] 1.9846
# [1563.5619062185287, 1574.6630824804306, 1573.0074135065079]
# 0
# Epoch [115/200], Discriminator 0.3292, Best Generator[0] 3.3681
# [1524.212054491043, 1513.8935667276382, 1517.441233754158]
# 1
# Epoch [116/200], Discriminator 0.5142, Best Generator[1] 2.5344
# [1588.152222275734, 1607.8157675266266, 1597.0322246551514]
# 0
# Epoch [117/200], Discriminator 0.3342, Best Generator[0] 2.8066
# [1505.9154537916183, 1506.2584232091904, 1494.0520714521408]
# 2
# Epoch [118/200], Discriminator 0.5348, Best Generator[2] 2.0522
# [1565.4233503341675, 1564.4299248456955, 1568.5124822854996]
# 1
# Epoch [119/200], Discriminator 0.4644, Best Generator[1] 3.1348
# [1527.3666722774506, 1523.7540543079376, 1523.0193756818771]
# 2
# Epoch [120/200], Discriminator 0.2909, Best Generator[2] 2.6757
# [1551.584155201912, 1542.7435824871063, 1535.1876047849655]
# 2
# Epoch [121/200], Discriminator 0.4397, Best Generator[2] 2.2774
# [1502.360227227211, 1507.5017111301422, 1503.6572946310043]
# 0
# Epoch [122/200], Discriminator 0.4365, Best Generator[0] 2.5986
# [1571.6702563762665, 1566.3732662200928, 1561.374286532402]
# 2
# Epoch [123/200], Discriminator 0.4869, Best Generator[2] 2.2180
# [1493.6074701547623, 1488.097225189209, 1493.1008623838425]
# 1
# Epoch [124/200], Discriminator 0.3804, Best Generator[1] 2.0918
# [1508.7444732189178, 1501.6838368177414, 1503.9415380954742]
# 1
# Epoch [125/200], Discriminator 0.4520, Best Generator[1] 1.9533
# [1485.4433999061584, 1488.729238986969, 1479.235715508461]
# 2
# Epoch [126/200], Discriminator 0.3644, Best Generator[2] 2.1235
# [1506.1425867080688, 1501.5119638442993, 1488.6640377044678]
# 2
# Epoch [127/200], Discriminator 0.3007, Best Generator[2] 2.8895
# [1554.3796261548996, 1559.7504261732101, 1563.0026803016663]
# 0
# Epoch [128/200], Discriminator 0.3583, Best Generator[0] 3.5272
# [1480.6524077653885, 1479.8935638666153, 1475.806314587593]
# 2
# Epoch [129/200], Discriminator 0.4637, Best Generator[2] 2.2776
# [1515.7041107416153, 1517.2935268878937, 1504.38820374012]
# 2
# Epoch [130/200], Discriminator 0.5389, Best Generator[2] 2.2973
# [1514.4650205373764, 1525.6571609973907, 1516.113233923912]
# 0
# Epoch [131/200], Discriminator 0.2780, Best Generator[0] 2.9860
# [1505.6305093765259, 1496.2530263662338, 1499.5383979082108]
# 1
# Epoch [132/200], Discriminator 0.4275, Best Generator[1] 2.8928
# [1562.978820681572, 1560.8543792963028, 1557.642138004303]
# 2
# Epoch [133/200], Discriminator 0.3795, Best Generator[2] 3.2499
# [1479.2152745723724, 1484.0381548404694, 1482.292736530304]
# 0
# Epoch [134/200], Discriminator 0.5002, Best Generator[0] 1.9851
# [1502.2372711896896, 1500.1567200422287, 1494.3741698265076]
# 2
# Epoch [135/200], Discriminator 0.3286, Best Generator[2] 2.2483
# [1533.316679596901, 1534.3874447345734, 1537.1079572439194]
# 0
# Epoch [136/200], Discriminator 0.3595, Best Generator[0] 2.5556
# [1493.5287947654724, 1489.5429607629776, 1483.9750032424927]
# 2
# Epoch [137/200], Discriminator 0.3839, Best Generator[2] 2.2672
# [1477.450178027153, 1480.2727253437042, 1484.2641817331314]
# 0
# Epoch [138/200], Discriminator 0.4160, Best Generator[0] 2.2924
# [1553.0451806783676, 1560.776739358902, 1560.395278453827]
# 0
# Epoch [139/200], Discriminator 0.4949, Best Generator[0] 2.1902
# [1484.2512410879135, 1479.2227041721344, 1482.622451543808]
# 1
# Epoch [140/200], Discriminator 0.4995, Best Generator[1] 1.8323
# [1505.566464304924, 1503.6392484903336, 1503.1013417243958]
# 2
# Epoch [141/200], Discriminator 0.5479, Best Generator[2] 1.7231
# [1534.975099682808, 1522.4411087036133, 1534.3367774486542]
# 1
# Epoch [142/200], Discriminator 0.3233, Best Generator[1] 2.1945
# [1499.0766245126724, 1495.2029505968094, 1495.4295637607574]
# 1
# Epoch [143/200], Discriminator 0.5072, Best Generator[1] 1.9682
# [1488.592490553856, 1487.491052389145, 1481.5207693576813]
# 2
# Epoch [144/200], Discriminator 0.3981, Best Generator[2] 2.2905
# [1516.7483088970184, 1515.0902421474457, 1518.8945952653885]
# 1
# Epoch [145/200], Discriminator 0.3866, Best Generator[1] 2.1474
# [1515.2553762197495, 1508.3793843984604, 1513.391816020012]
# 1
# Epoch [146/200], Discriminator 0.3635, Best Generator[1] 2.9558
# [1512.5528291463852, 1513.7578033208847, 1518.12142765522]
# 0
# Epoch [147/200], Discriminator 0.6064, Best Generator[0] 2.3216
# [1518.7493448257446, 1519.0147503614426, 1516.8325761556625]
# 2
# Epoch [148/200], Discriminator 0.4070, Best Generator[2] 2.1214
# [1504.9601417779922, 1511.7284994125366, 1509.0256326198578]
# 0
# Epoch [149/200], Discriminator 0.3909, Best Generator[0] 2.1273
# [1514.969830274582, 1517.2903122901917, 1525.7328029870987]
# 0
# Epoch [150/200], Discriminator 0.4156, Best Generator[0] 2.1936
# [1487.258496761322, 1483.6124523878098, 1483.148822426796]
# 2
# Epoch [151/200], Discriminator 0.3513, Best Generator[2] 2.1149
# [1511.2881681919098, 1521.4673435688019, 1513.6299065351486]
# 0
# Epoch [152/200], Discriminator 0.3867, Best Generator[0] 2.3372
# [1529.1997250318527, 1528.9704580307007, 1527.6630021333694]
# 2
# Epoch [153/200], Discriminator 0.3246, Best Generator[2] 2.1161
# [1543.457934975624, 1540.356626033783, 1541.2485231161118]
# 1
# Epoch [154/200], Discriminator 0.3884, Best Generator[1] 2.2056
# [1495.437633395195, 1482.6729744672775, 1492.11856508255]
# 1
# Epoch [155/200], Discriminator 0.3405, Best Generator[1] 2.5541
# [1536.1253052949905, 1539.5219013690948, 1536.5796040296555]
# 0
# Epoch [156/200], Discriminator 0.3329, Best Generator[0] 2.3143
# [1521.8028382062912, 1517.5516372919083, 1519.2307299375534]
# 1
# Epoch [157/200], Discriminator 0.4170, Best Generator[1] 2.0909
# [1523.8576934337616, 1527.2019815444946, 1525.048087477684]
# 0
# Epoch [158/200], Discriminator 0.3783, Best Generator[0] 2.7973
# [1531.8868672847748, 1532.3638373613358, 1533.709709405899]
# 0
# Epoch [159/200], Discriminator 0.4012, Best Generator[0] 2.0877
# [1479.8724287748337, 1478.333989739418, 1476.9233100414276]
# 2
# Epoch [160/200], Discriminator 0.4577, Best Generator[2] 2.1045
# [1559.3769011497498, 1551.0910549163818, 1553.8374594449997]
# 1
# Epoch [161/200], Discriminator 0.2975, Best Generator[1] 2.9137
# [1484.0194835662842, 1488.9005366563797, 1485.7683889865875]
# 0
# Epoch [162/200], Discriminator 0.5082, Best Generator[0] 2.8566
# [1511.8007827997208, 1514.304793715477, 1516.298893213272]
# 0
# Epoch [163/200], Discriminator 0.4305, Best Generator[0] 2.4308
# [1545.9790592193604, 1548.3236566781998, 1547.469094634056]
# 0
# Epoch [164/200], Discriminator 0.3737, Best Generator[0] 2.6616
# [1503.1202479600906, 1505.139753818512, 1503.8703190088272]
# 0
# Epoch [165/200], Discriminator 0.4585, Best Generator[0] 2.5130
# [1488.5618901252747, 1490.040153503418, 1489.6933522224426]
# 0
# Epoch [166/200], Discriminator 0.2508, Best Generator[0] 2.3889
# [1558.2697261571884, 1560.3706085681915, 1558.0359864234924]
# 2
# Epoch [167/200], Discriminator 0.4424, Best Generator[2] 2.0074
# [1519.0375226736069, 1521.7432112693787, 1524.5064313411713]
# 0
# Epoch [168/200], Discriminator 0.3447, Best Generator[0] 2.4179
# [1499.425875902176, 1499.5926957130432, 1498.8466987609863]
# 2
# Epoch [169/200], Discriminator 0.3150, Best Generator[2] 2.3265
# [1519.9725170135498, 1521.6947349309921, 1524.0451850891113]
# 0
# Epoch [170/200], Discriminator 0.2355, Best Generator[0] 2.7351
# [1491.2765899896622, 1490.4291932582855, 1492.3918702602386]
# 1
# Epoch [171/200], Discriminator 0.3065, Best Generator[1] 2.1565
# [1534.3957295417786, 1544.879317998886, 1543.1798275709152]
# 0
# Epoch [172/200], Discriminator 0.4222, Best Generator[0] 2.2720
# [1514.8216552734375, 1514.3447824716568, 1510.109546303749]
# 2
# Epoch [173/200], Discriminator 0.3164, Best Generator[2] 2.6485
# [1501.967797279358, 1500.030021905899, 1496.163868546486]
# 2
# Epoch [174/200], Discriminator 0.2378, Best Generator[2] 2.9381
# [1568.2496575117111, 1565.3477185964584, 1567.717943906784]
# 1
# Epoch [175/200], Discriminator 0.3947, Best Generator[1] 3.1195
# [1527.9456627368927, 1522.779978275299, 1531.7592568397522]
# 1
# Epoch [176/200], Discriminator 0.3107, Best Generator[1] 2.5645
# [1509.9358214139938, 1509.1296533346176, 1513.546620965004]
# 1
# Epoch [177/200], Discriminator 0.3948, Best Generator[1] 2.2169
# [1537.544583082199, 1538.7604978084564, 1526.442447423935]
# 2
# Epoch [178/200], Discriminator 0.2539, Best Generator[2] 3.2866
# [1498.0317239761353, 1501.316214799881, 1506.521394610405]
# 0
# Epoch [179/200], Discriminator 0.4277, Best Generator[0] 2.4425
# [1547.329042315483, 1556.3875887393951, 1547.9962064027786]
# 0
# Epoch [180/200], Discriminator 0.3812, Best Generator[0] 2.3097
# [1513.6539220809937, 1510.741777420044, 1505.1962448358536]
# 2
# Epoch [181/200], Discriminator 0.3836, Best Generator[2] 2.3872
# [1501.1424748897552, 1499.119481921196, 1499.413797736168]
# 1
# Epoch [182/200], Discriminator 0.3468, Best Generator[1] 2.6241
# [1545.7493951320648, 1542.686180472374, 1534.740374326706]
# 2
# Epoch [183/200], Discriminator 0.3326, Best Generator[2] 2.7999
# [1495.7873775959015, 1501.602201461792, 1497.8480862379074]
# 0
# Epoch [184/200], Discriminator 0.4105, Best Generator[0] 2.6070
# [1523.4271584749222, 1523.3951208591461, 1525.9573068618774]
# 1
# Epoch [185/200], Discriminator 0.3107, Best Generator[1] 3.1812
# [1538.4572432041168, 1536.7297135591507, 1537.9661412239075]
# 1
# Epoch [186/200], Discriminator 0.3038, Best Generator[1] 2.7128
# [1504.908961892128, 1508.586292386055, 1502.3743433952332]
# 2
# Epoch [187/200], Discriminator 0.3168, Best Generator[2] 2.4996
# [1541.1641504764557, 1529.6973561048508, 1536.5275939702988]
# 1
# Epoch [188/200], Discriminator 0.3182, Best Generator[1] 2.2436
# [1525.4542564153671, 1524.9309412240982, 1531.6640920639038]
# 1
# Epoch [189/200], Discriminator 0.4076, Best Generator[1] 2.0907
# [1546.1289781332016, 1547.5407302379608, 1540.9230256080627]
# 2
# Epoch [190/200], Discriminator 0.3372, Best Generator[2] 2.5792
# [1516.4549168348312, 1521.1177790164948, 1521.0142983198166]
# 0
# Epoch [191/200], Discriminator 0.2472, Best Generator[0] 2.2368
# [1506.4147859811783, 1507.2420328855515, 1504.3471035957336]
# 2
# Epoch [192/200], Discriminator 0.3341, Best Generator[2] 2.5701
# [1526.1079325675964, 1522.8193444013596, 1522.6547175645828]
# 2
# Epoch [193/200], Discriminator 0.4046, Best Generator[2] 2.1629
# [1511.2772455215454, 1511.654990553856, 1513.3317400217056]
# 0
# Epoch [194/200], Discriminator 0.2274, Best Generator[0] 2.9093
# [1521.7146602869034, 1512.9308743476868, 1513.678702712059]
# 1
# Epoch [195/200], Discriminator 0.3625, Best Generator[1] 2.2326
# [1559.5171629190445, 1560.6896797418594, 1563.7991429567337]
# 0
# Epoch [196/200], Discriminator 0.2590, Best Generator[0] 2.7636
# [1518.3562062978745, 1517.6825907230377, 1513.9645272493362]
# 2
# Epoch [197/200], Discriminator 0.3211, Best Generator[2] 2.2855
# [1518.526426434517, 1513.3049750328064, 1518.6923640966415]
# 1
# Epoch [198/200], Discriminator 0.3252, Best Generator[1] 2.6793
# [1560.254365324974, 1566.7148789167404, 1558.8326466083527]
# 2
# Epoch [199/200], Discriminator 0.2455, Best Generator[2] 2.5967
# [1503.173082113266, 1499.3862122297287, 1497.6482543945312]
# 2
# Epoch [200/200], Discriminator 0.4245, Best Generator[2] 2.8823

# %%
# Plot the Loss for Generator and Discriminator
lossManager.drawLossPlot(showPlot = True, savePlot = False)

# %%
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Min Co-Operative GAN')
plt.plot(lossManager.getGeneratorLoss(), label='Generator Loss')
plt.plot(lossManager.getDiscriminatorLoss(), label='Discriminator Loss')
legend = plt.legend(loc='upper right', shadow=True)
#plt.show()
plt.savefig('Loss_Plot_Vanilla_Min_Co-Operative_GAN_'+str(num_epochs)+'.png')
#lossManager.drawLossPlot(showPlot = True, savePlot = False, genList = True)

# %%
lossManager.drawLossPlot(showPlot = True, savePlot = False, genList = True)

# %%
#lossL = lossManager.getGeneratorsList()

# %%
# Generate GIF
generate_animation(path, num_epochs, 'Min_Multiple_Gens')

# %%
# Save the model
    torch.save(Generators[BestPerformingGenerator].state_dict(), './Generator.pkl')
torch.save(Discriminator.state_dict(), './Discriminator.pkl')
pickle.dump(lossManager, open( "LossManager.pkl", "wb" ))

# %%
# Load Loss Manager for viewing data of 200 iterations
#lossManagerTrained = pickle.load(open( "200Iteration/LossManager.pkl", "rb" ))

# %%
#drawLossPlot(lossManagerTrained.getGeneratorLoss(), lossManagerTrained.getDiscriminatorLoss(), showPlot = False, savePlot = True, loc = "200Iteration")
#drawLossPlot(lossManagerTrained.getGeneratorLoss(), lossManagerTrained.getDiscriminatorLoss(), showPlot = True, savePlot = False, loc = "200Iteration")

# %%
# Load model for debugging and testing
#Generator.load_state_dict(torch.load('Generator200.pkl'))
#Discriminator.load_state_dict(torch.load('Discriminator200.pkl'))
