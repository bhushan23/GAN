# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets
from torchvision import transforms
import torchvision
import os
import numpy as np
import matplotlib.pyplot as plt
import torchvision.utils as tutils
import imageio
import pickle
import copy
from PIL import Image
import random

# %%
# Options being used 
batch_size = 100
imgDim = 28
path = './genImg/'
showPlot = False
savePlot = True
num_epochs = 200
IS_CUDA = False

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                     std=(0.5, 0.5, 0.5))])

# %%
# MNIST dataset
dataset = datasets.MNIST(root='../../data',
                         train=True,
                         transform=transform,
                         download=True)
# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

# %%
# Helper routines
if torch.cuda.is_available():
    IS_CUDA = True
    
def var(x):
    if IS_CUDA:
        x = x.cuda()
    return Variable(x)

def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
    
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

def generate_animation(root, epoch, name):
    images = []
    for e in range(epoch):
        img_name = root+'/image_'+str(e)+'.png'
        images.append(imageio.imread(img_name))
    imageio.mimsave(root+ '/' + name +'.gif', images, fps=5)

def save_image(pic, path):
    grid = torchvision.utils.make_grid(pic, nrow=8, padding=2)
    ndarr = grid.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
    im = Image.fromarray(ndarr)
    im.save(path)

class LossModule: 
    def __init__(self, numberOfGens = 1):
        self.D_loss = []
        self.G_loss = []
        self.Many_G_loss = [[]] * (numberOfGens)

    def insertDiscriminatorLoss(self, lossVal):
        self.D_loss.append(lossVal)
    
    def insertGeneratorLoss(self, lossVal):
        self.G_loss.append(lossVal)
    
    def insertGeneratorList(self, lossList):
        for i in range(0, len(lossList)):
            self.Many_G_loss[i].append(lossList[i])
        
    def getDiscriminatorLoss(self):
        return self.D_loss
    
    def getGeneratorLoss(self):
        return self.G_loss
    
    def getGeneratorsList(self):
        return self.Many_G_loss
    
    def drawLossPlot(self, showPlot = False, savePlot = True, label = "Vanilla GAN Loss", genList = False):
        plt.xlabel('Iterations')
        plt.ylabel('Loss')
        plt.title(label)
        if genList == True:
            i = 0
            for each in self.Many_G_loss:
                i = i + 1
                plt.plot(each, label='Generator Loss {}'.format(i))
        else:
            plt.plot(self.G_loss, label='Generator Loss')
        plt.plot(self.D_loss, label='Discriminator Loss')
        legend = plt.legend(loc='upper right', shadow=True)

        if showPlot:
            plt.show()
        if savePlot:
            plt.savefig(label+'Loss_Plot_Vanilla_GAN_'+str(num_epochs)+'.png')

# %%
# Network
'''
Generator = nn.Sequential(
        nn.Linear(Generator_input, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 784),
        nn.Tanh())

Discriminator = nn.Sequential(
        nn.Linear(784, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256, 256),
        nn.LeakyReLU(0.2),
        nn.Linear(256,1),
        nn.Sigmoid())
'''
Discriminator = nn.Sequential(
            nn.Linear(784, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,1),
            nn.Sigmoid())

Generator_input = 64

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Linear(Generator_input, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Sequential(nn.Linear(256, 784), nn.Tanh())
        self.lR = nn.LeakyReLU(0.2)
            
    def forward(self, x):
        x = self.fc1(x)
        x = self.lR(x)
        x = self.fc2(x)
        x = self.lR(x)
        return self.fc3(x)


#Gen = Generator()
Generators = []
GOptimizers = []
NumberOfGenerators = 3
for i in range(NumberOfGenerators):
    #Generators.append(copy.deepcopy(Generator))
    Generators.append(Generator())

if IS_CUDA:
    Discriminator.cuda()
    for each in Generators:
        each.cuda()

# %%
lossManager = LossModule(numberOfGens = NumberOfGenerators)
lossCriterion = nn.BCELoss()
D_opt = torch.optim.Adam(Discriminator.parameters(), lr = 0.0001)
#G_opt = torch.optim.Adam(Gen.parameters(), lr = 0.0001)
GOptimizers = []
for each in Generators:
    GOptimizers.append(torch.optim.Adam(each.parameters(), lr = 0.0001))

fixed_x = var(torch.randn(batch_size, Generator_input))

GeneratorLoss = []
def backPropGenerator(index, GeneratorLoss):
    Generators[index].zero_grad()
    GeneratorLoss[index].backward()
    GOptimizers[index].step()

# %%
# load model by loading from best one
outputImages = []
def train(BestPerformingGenerator, num_epochs = 10, d_iter = 1):
    for epoch in range(num_epochs):
        lossList = [0.0] * NumberOfGenerators
        for data in data_loader:
            image, _  = data
            image = var(image.view(image.size(0),  -1))
            
            # Train Discriminator
            #for k in range(0, d_iter):
            for each in Generators:
                D_real = Discriminator(image)
                # For Log(1 - D(G(Z)))
                Z_noise = var(torch.randn(batch_size, Generator_input))
                #print Z_noise.shape
                #print type(Gen)
                G_fake = each(Z_noise) #Generators[BestPerformingGenerator](Z_noise)
                #print G_fake.shape
                D_fake = Discriminator(G_fake)

                # Calculate Discriminator Loss
                D_real_loss = lossCriterion(D_real, var(torch.ones(batch_size, 1)))
                D_fake_loss = lossCriterion(D_fake, var(torch.zeros(batch_size, 1)))
                D_loss = D_real_loss + D_fake_loss

                # Backprop Discriminator
                Discriminator.zero_grad()
                D_loss.backward()
                D_opt.step()
                #print 'Discriminator Loop for: {}: {}'.format(i, D_loss.data[0])
   
            # Find best performing Generator
            i = 0
            GeneratorLoss = []
            for each, each_opt in zip(Generators, GOptimizers):
                Z_noise = var(torch.randn(batch_size, Generator_input))
                G_fake = each(Z_noise)
                #print G_fake1.shape
                #print type(each)
                D_fake = Discriminator(G_fake)
                # Compute Generator Loss
                G_loss = lossCriterion(D_fake, var(torch.ones(batch_size, 1)))
                GeneratorLoss.append(G_loss)
                lossList[i] += (float(G_loss.data[0]))
                i = i + 1
                Discriminator.zero_grad()
                each.zero_grad()
                G_loss.backward()
                each_opt.step()
                #backPropGenerator(i, GeneratorLoss)
                #print 'Generator Loop for: {}: {}'.format(i, G_loss.data[0])
            
            #print lossList
            #print type(lossList[0])
        BestPerformingGenerator = random.randint(0, NumberOfGenerators-1)
        print lossList
        for i in range(0, NumberOfGenerators):
            if i != BestPerformingGenerator:
                prev = Generators[i]
                Generators[i] = Generator()
                Generators[i].load_state_dict(Generators[BestPerformingGenerator].state_dict())
                GOptimizers[i] = torch.optim.Adam(Generators[i].parameters(), lr = 0.0001)
                GOptimizers[i].load_state_dict(GOptimizers[BestPerformingGenerator].state_dict())
                #Generators[i] = copy.deepcopy(Generators[BestPerformingGenerator])
                #GOptimizers[i] = torch.optim.Adam(Generators[i].parameters(), lr = 0.0001)
                #copy.deepcopy(GOptimizers[BestPerformingGenerator])
                if Generators[i] == prev:
                    print 'SAME'

        #print epoch
        print BestPerformingGenerator
        print 'Epoch [{}/{}], Discriminator {:.4f}, Best Generator[{}] {:.4f}'.format(epoch+1, num_epochs, D_loss.data[0], BestPerformingGenerator, GeneratorLoss[BestPerformingGenerator].data[0])
        lossManager.insertDiscriminatorLoss(D_loss.data[0])
        lossManager.insertGeneratorLoss(G_loss.data[0])
        lossManager.insertGeneratorList(GeneratorLoss)
        pic = Generators[BestPerformingGenerator](var(torch.randn(batch_size, Generator_input)))
        pic = pic.view(pic.size(0), 1, 28, 28) 
        pic = denorm(pic.data)
        outputImages.append(pic)
        #torchvision.utils.save_image(pic, path+'image_{}.png'.format(epoch))
        save_image(pic, path+'image_{}.png'.format(epoch))

# %%
num_epochs = 200
BestPerformingGenerator = train(0, num_epochs)
# Out:
# [3516.0893728733063, 3553.4120349884033, 3524.315729856491]
# 0
# Epoch [1/200], Discriminator 0.0482, Best Generator[0] 5.5260
# [3188.1363102197647, 3013.473253250122, 3111.129119873047]
# 2
# Epoch [2/200], Discriminator 0.0637, Best Generator[2] 4.2093
# [2919.795736312866, 2920.8583434820175, 2720.8586723804474]
# 2
# Epoch [3/200], Discriminator 0.0723, Best Generator[2] 4.4754
# [3251.831494808197, 3633.131567955017, 3304.335870027542]
# 1
# Epoch [4/200], Discriminator 0.0406, Best Generator[1] 2.1633
# [3461.7706914544106, 3394.1051422078162, 3297.8053308725357]
# 2
# Epoch [5/200], Discriminator 0.1208, Best Generator[2] 1.5245
# [3691.131488919258, 4351.826964080334, 3847.5337257385254]
# 2
# Epoch [6/200], Discriminator 0.0953, Best Generator[2] 3.7962
# [3445.682949960232, 3748.928174495697, 3613.0425493717194]
# 0
# Epoch [7/200], Discriminator 0.3272, Best Generator[0] 7.6437
# [4007.812032222748, 4214.567464232445, 4457.036749124527]
# 0
# Epoch [8/200], Discriminator 0.0408, Best Generator[0] 6.0065
# [4700.021144270897, 4335.579268813133, 4239.583868265152]
# 2
# Epoch [9/200], Discriminator 0.1582, Best Generator[2] 5.1050
# [4489.276176929474, 4607.740703225136, 4378.527111649513]
# 1
# Epoch [10/200], Discriminator 0.1552, Best Generator[1] 6.0380
# [4807.400213778019, 4419.391524672508, 4540.184078216553]
# 2
# Epoch [11/200], Discriminator 0.1069, Best Generator[2] 9.1298
# [4538.585127711296, 4372.147338330746, 4260.8209891319275]
# 0
# Epoch [12/200], Discriminator 0.0500, Best Generator[0] 7.3906
# [4913.893590033054, 4629.043058753014, 4591.345630168915]
# 2
# Epoch [13/200], Discriminator 0.1230, Best Generator[2] 4.0455
# [4942.756451129913, 5076.0105991363525, 4565.074587345123]
# 1
# Epoch [14/200], Discriminator 0.1678, Best Generator[1] 5.8826
# [5009.718542337418, 5106.980684995651, 5128.967022180557]
# 2
# Epoch [15/200], Discriminator 0.1537, Best Generator[2] 5.1629
# [4412.66885098815, 4257.840541124344, 4256.436115264893]
# 2
# Epoch [16/200], Discriminator 0.0577, Best Generator[2] 9.8996
# [4429.4601464271545, 4051.8789023160934, 4259.9303505420685]
# 0
# Epoch [17/200], Discriminator 0.0945, Best Generator[0] 7.3260
# [4394.222318351269, 4454.271662548184, 4271.066529750824]
# 1
# Epoch [18/200], Discriminator 0.1809, Best Generator[1] 4.7227
# [4380.641548968852, 4146.81446531415, 4278.174795150757]
# 0
# Epoch [19/200], Discriminator 0.1875, Best Generator[0] 7.9322
# [4246.124356985092, 4167.6079672575, 4319.423867583275]
# 1
# Epoch [20/200], Discriminator 0.3287, Best Generator[1] 5.2168
# [4224.387233257294, 4330.289532184601, 4131.952845811844]
# 1
# Epoch [21/200], Discriminator 0.2024, Best Generator[1] 3.6136
# [4127.924648761749, 4348.264962673187, 4116.628538131714]
# 1
# Epoch [22/200], Discriminator 0.0676, Best Generator[1] 6.9385
# [3916.9310190677643, 3922.837876021862, 3785.78821849823]
# 0
# Epoch [23/200], Discriminator 0.7072, Best Generator[0] 8.1541
# [3847.5830711722374, 3803.599011220038, 3775.9919534027576]
# 1
# Epoch [24/200], Discriminator 0.2385, Best Generator[1] 4.2564
# [3636.245582342148, 3643.4256253242493, 3517.194757938385]
# 2
# Epoch [25/200], Discriminator 0.1374, Best Generator[2] 3.0534
# [3903.003509283066, 3828.1061449050903, 3824.9834966659546]
# 1
# Epoch [26/200], Discriminator 0.1725, Best Generator[1] 5.5187
# [3571.9392573833466, 3642.525607943535, 3430.6761285066605]
# 0
# Epoch [27/200], Discriminator 0.2823, Best Generator[0] 3.3786
# [3291.788351535797, 3411.6060750484467, 3346.2101497650146]
# 1
# Epoch [28/200], Discriminator 0.4082, Best Generator[1] 6.7784
# [3220.538286924362, 3368.4207649230957, 3273.388691663742]
# 0
# Epoch [29/200], Discriminator 0.2697, Best Generator[0] 7.4243
# [3275.0475866794586, 3346.650722026825, 3220.8753666877747]
# 0
# Epoch [30/200], Discriminator 0.1916, Best Generator[0] 4.4447
# [2857.8818398714066, 3036.6324011087418, 2973.300470352173]
# 2
# Epoch [31/200], Discriminator 0.2145, Best Generator[2] 3.5335
# [2869.2629351615906, 2859.495909690857, 2902.4051535129547]
# 1
# Epoch [32/200], Discriminator 0.2906, Best Generator[1] 3.5876
# [2799.3668464422226, 2720.1041852235794, 2791.5210983753204]
# 2
# Epoch [33/200], Discriminator 0.4322, Best Generator[2] 2.3024
# [2749.371819972992, 2594.5443589687347, 2609.978651404381]
# 1
# Epoch [34/200], Discriminator 0.3747, Best Generator[1] 3.2504
# [2574.0565598011017, 2583.13951253891, 2483.225118994713]
# 0
# Epoch [35/200], Discriminator 0.2495, Best Generator[0] 4.2184
# [2606.886399745941, 2507.5718286037445, 2526.805540919304]
# 2
# Epoch [36/200], Discriminator 0.2397, Best Generator[2] 3.8057
# [2646.632611989975, 2464.88887155056, 2403.234848022461]
# 1
# Epoch [37/200], Discriminator 0.5137, Best Generator[1] 3.4313
# [2335.118156194687, 2362.7211017608643, 2410.6675505638123]
# 1
# Epoch [38/200], Discriminator 0.2537, Best Generator[1] 5.1862
# [2242.284009218216, 2323.388747215271, 2230.443393588066]
# 0
# Epoch [39/200], Discriminator 0.4021, Best Generator[0] 1.5665
# [2201.9025872945786, 2317.265099644661, 2310.257294654846]
# 2
# Epoch [40/200], Discriminator 0.3260, Best Generator[2] 3.3437
# [2307.661681354046, 2334.71788918972, 2403.3140419721603]
# 2
# Epoch [41/200], Discriminator 0.3340, Best Generator[2] 3.4948
# [2271.6684563159943, 2314.802540540695, 2422.255640268326]
# 2
# Epoch [42/200], Discriminator 0.2765, Best Generator[2] 3.2989
# [2365.0606268644333, 2457.3749338388443, 2371.6327016353607]
# 0
# Epoch [43/200], Discriminator 0.5241, Best Generator[0] 2.0246
# [2336.7156898379326, 2282.1191994547844, 2408.7385606765747]
# 0
# Epoch [44/200], Discriminator 0.3534, Best Generator[0] 2.6675
# [2439.609871149063, 2410.986724972725, 2355.1417080163956]
# 1
# Epoch [45/200], Discriminator 0.2648, Best Generator[1] 2.4487
# [2356.5570710897446, 2400.6867320537567, 2167.8639087677]
# 1
# Epoch [46/200], Discriminator 0.2542, Best Generator[1] 5.3860
# [2485.142323255539, 2457.1831993460655, 2664.2836027145386]
# 2
# Epoch [47/200], Discriminator 0.3983, Best Generator[2] 2.7865
# [2796.2638685703278, 2824.3212220668793, 2873.582153558731]
# 0
# Epoch [48/200], Discriminator 0.1910, Best Generator[0] 2.1581
# [2525.364932179451, 2688.0976009368896, 2385.228995323181]
# 2
# Epoch [49/200], Discriminator 0.2222, Best Generator[2] 2.8850
# [2173.721455216408, 2124.0850400924683, 2336.473187804222]
# 0
# Epoch [50/200], Discriminator 0.3126, Best Generator[0] 1.7685
# [2176.0133075118065, 2173.426180124283, 2455.587746024132]
# 0
# Epoch [51/200], Discriminator 0.2195, Best Generator[0] 2.6681
# [2431.9505848884583, 2143.4333894252777, 2081.6482297182083]
# 1
# Epoch [52/200], Discriminator 0.3691, Best Generator[1] 3.0262
# [2465.9402515888214, 2222.3884629011154, 2152.9922281503677]
# 1
# Epoch [53/200], Discriminator 0.4035, Best Generator[1] 4.1896
# [3289.530506849289, 2592.273346543312, 2847.3944141864777]
# 0
# Epoch [54/200], Discriminator 0.2129, Best Generator[0] 4.8848
# [3324.520593047142, 4445.034510612488, 3586.0321278572083]
# 0
# Epoch [55/200], Discriminator 0.4680, Best Generator[0] 4.5165
# [2184.7160844802856, 2219.175700902939, 2160.5543817281723]
# 1
# Epoch [56/200], Discriminator 0.2438, Best Generator[1] 3.6966
# [2284.2678748369217, 2238.1043441295624, 2186.235820531845]
# 0
# Epoch [57/200], Discriminator 0.4047, Best Generator[0] 3.0100
# [2155.511880993843, 2131.1180262565613, 2046.6508882045746]
# 1
# Epoch [58/200], Discriminator 0.1926, Best Generator[1] 3.3110
# [2024.8359795808792, 2061.639768719673, 1982.9946143627167]
# 0
# Epoch [59/200], Discriminator 0.5463, Best Generator[0] 2.3039
# [1974.0955032110214, 1967.8726583719254, 1943.629404783249]
# 2
# Epoch [60/200], Discriminator 0.4136, Best Generator[2] 3.7893
# [1930.6197147369385, 1915.3444098234177, 1926.128618836403]
# 1
# Epoch [61/200], Discriminator 0.3017, Best Generator[1] 1.9917
# [1822.4134011268616, 1834.2767782211304, 1843.5458512306213]
# 2
# Epoch [62/200], Discriminator 0.2936, Best Generator[2] 4.2723
# [1822.1819388866425, 1827.146359205246, 1821.2443829774857]
# 1
# Epoch [63/200], Discriminator 0.2085, Best Generator[1] 3.3708
# [1785.2036012411118, 1796.7587958574295, 1819.036175608635]
# 0
# Epoch [64/200], Discriminator 0.2450, Best Generator[0] 2.8019
# [1736.1672741174698, 1737.5106527805328, 1733.1018810272217]
# 0
# Epoch [65/200], Discriminator 0.3945, Best Generator[0] 2.3882
# [1785.7766510248184, 1782.6668764352798, 1800.82033765316]
# 1
# Epoch [66/200], Discriminator 0.2839, Best Generator[1] 3.1026
# [1805.3939286470413, 1823.8645001649857, 1808.9679116010666]
# 1
# Epoch [67/200], Discriminator 0.2393, Best Generator[1] 3.5552
# [1812.7137103676796, 1805.123771905899, 1807.066513121128]
# 2
# Epoch [68/200], Discriminator 0.3269, Best Generator[2] 2.1874
# [1761.2504078149796, 1770.961256146431, 1812.2516812086105]
# 0
# Epoch [69/200], Discriminator 0.2846, Best Generator[0] 3.7913
# [1823.1015349626541, 1815.3399398326874, 1784.0963399410248]
# 0
# Epoch [70/200], Discriminator 0.2334, Best Generator[0] 3.7949
# [1817.6380388736725, 1901.0877356529236, 1843.0785947442055]
# 2
# Epoch [71/200], Discriminator 0.3772, Best Generator[2] 2.6850
# [1877.9478800296783, 1897.3102934360504, 1827.4584022760391]
# 1
# Epoch [72/200], Discriminator 0.2525, Best Generator[1] 4.0637
# [1981.2655729055405, 2234.8904272317886, 2140.057740211487]
# 1
# Epoch [73/200], Discriminator 0.3899, Best Generator[1] 3.3260
# [2128.855072259903, 2396.825093269348, 2405.6241530179977]
# 2
# Epoch [74/200], Discriminator 0.2800, Best Generator[2] 4.4742
# [2770.619841814041, 2557.588997721672, 2627.511308193207]
# 2
# Epoch [75/200], Discriminator 0.2065, Best Generator[2] 4.4826
# [2553.145568728447, 2393.5912940502167, 2213.962499678135]
# 1
# Epoch [76/200], Discriminator 0.4509, Best Generator[1] 2.7592
# [2023.4477291107178, 2053.4516240358353, 1989.9561109542847]
# 0
# Epoch [77/200], Discriminator 0.3252, Best Generator[0] 4.0797
# [2023.6344027519226, 1975.9115422964096, 2042.3288456201553]
# 1
# Epoch [78/200], Discriminator 0.4158, Best Generator[1] 2.4707
# [1847.0795208215714, 1940.379269361496, 1858.0618870258331]
# 1
# Epoch [79/200], Discriminator 0.3309, Best Generator[1] 2.5529
# [2010.4641202688217, 2045.8279445171356, 1973.031701207161]
# 2
# Epoch [80/200], Discriminator 0.2540, Best Generator[2] 2.5605
# [1857.802048921585, 1889.2664867639542, 1874.275771856308]
# 2
# Epoch [81/200], Discriminator 0.1873, Best Generator[2] 4.2623
# [1814.1146638393402, 1815.6725766658783, 1820.648117184639]
# 0
# Epoch [82/200], Discriminator 0.3186, Best Generator[0] 2.8164
# [1736.4085224866867, 1740.6894842386246, 1735.5686519145966]
# 2
# Epoch [83/200], Discriminator 0.2813, Best Generator[2] 3.2247
# [1711.5939053297043, 1708.9366545677185, 1708.47290122509]
# 1
# Epoch [84/200], Discriminator 0.2215, Best Generator[1] 3.3515
# [1693.5606122016907, 1692.5999252796173, 1693.4864873886108]
# 0
# Epoch [85/200], Discriminator 0.3645, Best Generator[0] 2.9474
# [1672.255705833435, 1679.2188999652863, 1664.5155590772629]
# 2
# Epoch [86/200], Discriminator 0.4673, Best Generator[2] 1.8218
# [1607.817813873291, 1616.142092704773, 1611.5911730527878]
# 2
# Epoch [87/200], Discriminator 0.3837, Best Generator[2] 2.5070
# [1587.56512093544, 1586.6362544298172, 1594.2811337709427]
# 0
# Epoch [88/200], Discriminator 0.3734, Best Generator[0] 2.3209
# [1614.5964153409004, 1612.5896748304367, 1615.0793364048004]
# 1
# Epoch [89/200], Discriminator 0.2752, Best Generator[1] 2.9253
# [1582.72727560997, 1584.1528055667877, 1589.0944027900696]
# 2
# Epoch [90/200], Discriminator 0.3612, Best Generator[2] 2.3273
# [1598.4247860908508, 1603.5232976675034, 1598.0619586706161]
# 0
# Epoch [91/200], Discriminator 0.3288, Best Generator[0] 1.9857
# [1644.104572057724, 1636.3872559070587, 1644.1217000484467]
# 0
# Epoch [92/200], Discriminator 0.3635, Best Generator[0] 2.1679
# [1636.1004194021225, 1646.1322763562202, 1642.8931021690369]
# 2
# Epoch [93/200], Discriminator 0.4450, Best Generator[2] 1.7965
# [1652.3945269584656, 1641.6044714450836, 1648.2836532592773]
# 0
# Epoch [94/200], Discriminator 0.4748, Best Generator[0] 2.3674
# [1565.730968952179, 1581.8247883319855, 1561.5668631792068]
# 1
# Epoch [95/200], Discriminator 0.3771, Best Generator[1] 3.1787
# [1796.846325993538, 1773.2209994792938, 1767.6698001623154]
# 2
# Epoch [96/200], Discriminator 0.4422, Best Generator[2] 3.1732
# [1694.4598466157913, 1693.13780772686, 1702.8426119089127]
# 0
# Epoch [97/200], Discriminator 0.5409, Best Generator[0] 2.9008
# [1625.0624113082886, 1632.0135964155197, 1636.325577378273]
# 2
# Epoch [98/200], Discriminator 0.4181, Best Generator[2] 2.2950
# [1609.0353907346725, 1605.9343048334122, 1608.6876312494278]
# 1
# Epoch [99/200], Discriminator 0.4206, Best Generator[1] 2.0360
# [1649.0568815469742, 1656.8684635162354, 1669.0345641374588]
# 1
# Epoch [100/200], Discriminator 0.2496, Best Generator[1] 3.0833
# [1617.5918375253677, 1617.4272102117538, 1618.6917011737823]
# 1
# Epoch [101/200], Discriminator 0.2932, Best Generator[1] 2.7401
# [1612.3873965740204, 1613.6087995767593, 1622.2074904441833]
# 0
# Epoch [102/200], Discriminator 0.5398, Best Generator[0] 2.0865
# [1607.5541044473648, 1610.1599895954132, 1609.7579687833786]
# 1
# Epoch [103/200], Discriminator 0.4005, Best Generator[1] 2.9027
# [1619.4891737699509, 1629.9551348686218, 1614.9392236471176]
# 1
# Epoch [104/200], Discriminator 0.2982, Best Generator[1] 2.4140
# [1609.836255788803, 1606.9043879508972, 1610.9031500816345]
# 2
# Epoch [105/200], Discriminator 0.2677, Best Generator[2] 2.4857
# [1612.239374279976, 1625.9827417135239, 1629.1826593875885]
# 2
# Epoch [106/200], Discriminator 0.3590, Best Generator[2] 2.2471
# [1594.3803853988647, 1588.4322901964188, 1600.843353152275]
# 1
# Epoch [107/200], Discriminator 0.2776, Best Generator[1] 2.2040
# [1591.3338655233383, 1596.8026107549667, 1598.827899813652]
# 0
# Epoch [108/200], Discriminator 0.4348, Best Generator[0] 2.2039
# [1590.9891197681427, 1585.2916662693024, 1573.4702112674713]
# 2
# Epoch [109/200], Discriminator 0.3323, Best Generator[2] 2.6510
# [1516.0652785301208, 1504.9175761938095, 1505.1854544878006]
# 0
# Epoch [110/200], Discriminator 0.4192, Best Generator[0] 2.6703
# [1488.8802785873413, 1487.343605875969, 1483.908843278885]
# 1
# Epoch [111/200], Discriminator 0.2346, Best Generator[1] 3.0578
# [1600.971808552742, 1598.9230036735535, 1600.3839230537415]
# 2
# Epoch [112/200], Discriminator 0.2235, Best Generator[2] 2.7554
# [1620.1047902107239, 1622.8738666772842, 1611.929374575615]
# 0
# Epoch [113/200], Discriminator 0.3536, Best Generator[0] 3.3917
# [1592.5083929300308, 1594.344404220581, 1588.9188371896744]
# 1
# Epoch [114/200], Discriminator 0.4588, Best Generator[1] 2.6789
# [1531.4901288747787, 1543.218309044838, 1544.4224926233292]
# 1
# Epoch [115/200], Discriminator 0.2922, Best Generator[1] 2.9134
# [1541.4931485652924, 1552.756912469864, 1548.879365324974]
# 2
# Epoch [116/200], Discriminator 0.2886, Best Generator[2] 3.4147
# [1527.2523118257523, 1536.2964853048325, 1533.5004023313522]
# 2
# Epoch [117/200], Discriminator 0.3602, Best Generator[2] 2.2013
# [1527.1599209308624, 1517.8448382616043, 1499.9769476652145]
# 0
# Epoch [118/200], Discriminator 0.2767, Best Generator[0] 2.5062
# [1557.3531596660614, 1567.0903599262238, 1555.4178184270859]
# 0
# Epoch [119/200], Discriminator 0.3600, Best Generator[0] 2.2408
# [1563.8074795007706, 1563.8907914161682, 1565.8388777971268]
# 1
# Epoch [120/200], Discriminator 0.3015, Best Generator[1] 2.3886
# [1473.8102836608887, 1472.4547958374023, 1497.5471585988998]
# 1
# Epoch [121/200], Discriminator 0.3945, Best Generator[1] 2.1904
# [1562.3302931785583, 1552.987920165062, 1557.728534936905]
# 2
# Epoch [122/200], Discriminator 0.2340, Best Generator[2] 3.6943
# [1579.598372220993, 1584.4922736883163, 1581.561432003975]
# 1
# Epoch [123/200], Discriminator 0.3986, Best Generator[1] 2.5933
# [1524.056443452835, 1527.4824640750885, 1521.7431449890137]
# 1
# Epoch [124/200], Discriminator 0.4010, Best Generator[1] 2.2250
# [1508.4209035634995, 1494.7821573019028, 1502.7170387506485]
# 2
# Epoch [125/200], Discriminator 0.3855, Best Generator[2] 2.7375
# [1494.8206222057343, 1492.4122904539108, 1496.745594382286]
# 1
# Epoch [126/200], Discriminator 0.3087, Best Generator[1] 2.6521
# [1455.9881418943405, 1460.129802107811, 1458.6242611408234]
# 0
# Epoch [127/200], Discriminator 0.3211, Best Generator[0] 2.7324
# [1473.7497699260712, 1472.9636796712875, 1473.8390078544617]
# 1
# Epoch [128/200], Discriminator 0.3413, Best Generator[1] 2.6390
# [1578.9671938419342, 1586.9339010715485, 1576.189282655716]
# 1
# Epoch [129/200], Discriminator 0.4637, Best Generator[1] 1.7588
# [1543.109993815422, 1534.4700014591217, 1534.7721682786942]
# 1
# Epoch [130/200], Discriminator 0.3879, Best Generator[1] 1.7971
# [1493.515270113945, 1505.3496012687683, 1503.6393060684204]
# 2
# Epoch [131/200], Discriminator 0.3572, Best Generator[2] 2.1791
# [1457.828186750412, 1459.2825063467026, 1459.8999364376068]
# 2
# Epoch [132/200], Discriminator 0.4620, Best Generator[2] 2.4075
# [1496.7066358327866, 1481.7742795944214, 1492.3325954675674]
# 2
# Epoch [133/200], Discriminator 0.3999, Best Generator[2] 2.6541
# [1463.4753959178925, 1470.466849565506, 1459.452035665512]
# 0
# Epoch [134/200], Discriminator 0.3116, Best Generator[0] 2.5780
# [1554.1800858974457, 1549.1406586170197, 1554.6278946399689]
# 2
# Epoch [135/200], Discriminator 0.3573, Best Generator[2] 2.6662
# [1503.676766872406, 1499.8862155675888, 1498.6281323432922]
# 0
# Epoch [136/200], Discriminator 0.5019, Best Generator[0] 2.0603
# [1455.8489096164703, 1455.7066110372543, 1449.7077127695084]
# 2
# Epoch [137/200], Discriminator 0.4876, Best Generator[2] 2.2814
# [1519.0591975450516, 1519.1380115747452, 1525.5392042398453]
# 0
# Epoch [138/200], Discriminator 0.2995, Best Generator[0] 2.5291
# [1476.129620552063, 1476.248951435089, 1479.4262857437134]
# 2
# Epoch [139/200], Discriminator 0.4882, Best Generator[2] 2.3632
# [1516.729868531227, 1512.1884038448334, 1515.9812104701996]
# 0
# Epoch [140/200], Discriminator 0.5333, Best Generator[0] 2.0389
# [1511.7939194440842, 1510.7657055854797, 1512.5277506113052]
# 1
# Epoch [141/200], Discriminator 0.3889, Best Generator[1] 2.5117
# [1483.4463263750076, 1483.014455318451, 1482.4028179645538]
# 2
# Epoch [142/200], Discriminator 0.5822, Best Generator[2] 2.0751
# [1501.2135155200958, 1490.7812522649765, 1497.5624451637268]
# 0
# Epoch [143/200], Discriminator 0.3062, Best Generator[0] 2.3981
# [1449.6897344589233, 1454.958587050438, 1458.929198026657]
# 1
# Epoch [144/200], Discriminator 0.3560, Best Generator[1] 2.4587
# [1500.96222281456, 1502.7948161363602, 1504.6156532764435]
# 2
# Epoch [145/200], Discriminator 0.3977, Best Generator[2] 2.1738
# [1475.94324529171, 1463.3397904634476, 1469.3831515312195]
# 1
# Epoch [146/200], Discriminator 0.3219, Best Generator[1] 2.2718
# [1503.23968231678, 1511.804391860962, 1511.4518694877625]
# 2
# Epoch [147/200], Discriminator 0.4643, Best Generator[2] 2.4090
# [1459.633947134018, 1450.1185919046402, 1448.8793762922287]
# 2
# Epoch [148/200], Discriminator 0.3073, Best Generator[2] 2.6808
# [1524.7086310386658, 1515.6451728343964, 1521.5481668710709]
# 1
# Epoch [149/200], Discriminator 0.3167, Best Generator[1] 2.6597
# [1500.8021430969238, 1504.4965370893478, 1500.1159863471985]
# 2
# Epoch [150/200], Discriminator 0.4122, Best Generator[2] 2.4530
# [1489.707775592804, 1480.5048568248749, 1489.593869805336]
# 0
# Epoch [151/200], Discriminator 0.3699, Best Generator[0] 2.3271
# [1459.3667126893997, 1459.9909604787827, 1459.4767715930939]
# 2
# Epoch [152/200], Discriminator 0.4560, Best Generator[2] 2.3069
# [1537.3670622110367, 1530.9695703983307, 1523.5674892663956]
# 2
# Epoch [153/200], Discriminator 0.4059, Best Generator[2] 2.5462
# [1452.2438569068909, 1455.3644714355469, 1448.7661278247833]
# 1
# Epoch [154/200], Discriminator 0.3817, Best Generator[1] 2.6100
# [1502.8008456230164, 1503.4545531272888, 1497.080243587494]
# 2
# Epoch [155/200], Discriminator 0.3493, Best Generator[2] 2.3806
# [1466.4348524808884, 1471.6383539438248, 1469.0925232172012]
# 0
# Epoch [156/200], Discriminator 0.3263, Best Generator[0] 3.0651
# [1469.4560970067978, 1464.719654560089, 1466.756276845932]
# 0
# Epoch [157/200], Discriminator 0.3672, Best Generator[0] 2.2260
# [1512.5930205583572, 1515.441399216652, 1509.5030936002731]
# 0
# Epoch [158/200], Discriminator 0.3829, Best Generator[0] 2.0819
# [1457.0015436410904, 1461.6741099357605, 1463.6100602149963]
# 2
# Epoch [159/200], Discriminator 0.3894, Best Generator[2] 1.9833
# [1456.2555017471313, 1457.465197443962, 1458.43812251091]
# 2
# Epoch [160/200], Discriminator 0.2960, Best Generator[2] 2.6081
# [1503.2902817726135, 1502.2906346321106, 1499.5835379362106]
# 2
# Epoch [161/200], Discriminator 0.3172, Best Generator[2] 2.5354
# [1494.6988135576248, 1497.5233970880508, 1498.0633755922318]
# 2
# Epoch [162/200], Discriminator 0.4244, Best Generator[2] 2.3849
# [1467.1612844467163, 1464.4947148561478, 1456.8222156763077]
# 1
# Epoch [163/200], Discriminator 0.3526, Best Generator[1] 2.3680
# [1475.5604190826416, 1479.1019179821014, 1479.6581404209137]
# 1
# Epoch [164/200], Discriminator 0.3301, Best Generator[1] 2.6734
# [1483.7669795751572, 1482.9085278511047, 1480.2813893556595]
# 2
# Epoch [165/200], Discriminator 0.4087, Best Generator[2] 2.4839
# [1480.2760553359985, 1482.0661400556564, 1479.0030045509338]
# 2
# Epoch [166/200], Discriminator 0.3032, Best Generator[2] 2.6321
# [1496.6609966754913, 1493.0116653442383, 1496.7749683856964]
# 0
# Epoch [167/200], Discriminator 0.3802, Best Generator[0] 2.6029
# [1474.3097929954529, 1486.4210031032562, 1476.381058216095]
# 2
# Epoch [168/200], Discriminator 0.3207, Best Generator[2] 2.4729
# [1466.8297842741013, 1476.7673906087875, 1472.8812211751938]
# 1
# Epoch [169/200], Discriminator 0.2580, Best Generator[1] 2.2405
# [1459.7440314292908, 1454.6156454086304, 1464.1088902950287]
# 1
# Epoch [170/200], Discriminator 0.4185, Best Generator[1] 2.4614
# [1486.5121097564697, 1486.0298181772232, 1482.0284147262573]
# 2
# Epoch [171/200], Discriminator 0.3962, Best Generator[2] 2.5416
# [1470.3907718658447, 1477.7296876907349, 1478.6841537952423]
# 0
# Epoch [172/200], Discriminator 0.4305, Best Generator[0] 2.7398
# [1458.552829861641, 1459.750623703003, 1456.801685810089]
# 2
# Epoch [173/200], Discriminator 0.2848, Best Generator[2] 3.0063
# [1488.8441685438156, 1484.7715682983398, 1488.5303688049316]
# 0
# Epoch [174/200], Discriminator 0.2745, Best Generator[0] 2.3420
# [1462.7216728925705, 1464.7664620876312, 1464.8613884449005]
# 2
# Epoch [175/200], Discriminator 0.3969, Best Generator[2] 2.4968
# [1460.1013140678406, 1462.172881603241, 1455.719317317009]
# 0
# Epoch [176/200], Discriminator 0.4282, Best Generator[0] 2.4778
# [1465.7338607311249, 1465.9242275953293, 1471.8367542028427]
# 2
# Epoch [177/200], Discriminator 0.3489, Best Generator[2] 2.6773
# [1481.0163711309433, 1485.550794839859, 1486.1395823955536]
# 1
# Epoch [178/200], Discriminator 0.3988, Best Generator[1] 2.2174
# [1505.8989095687866, 1507.622160077095, 1509.4001709222794]
# 0
# Epoch [179/200], Discriminator 0.3173, Best Generator[0] 2.1742
# [1465.3624651432037, 1465.702114701271, 1469.2145113945007]
# 1
# Epoch [180/200], Discriminator 0.3895, Best Generator[1] 2.5935
# [1466.2898458242416, 1466.2612537145615, 1468.6495872735977]
# 2
# Epoch [181/200], Discriminator 0.3659, Best Generator[2] 2.1914
# [1462.3740102052689, 1460.3039745092392, 1466.7765522003174]
# 0
# Epoch [182/200], Discriminator 0.3935, Best Generator[0] 2.0049
# [1505.1563366651535, 1506.3502054214478, 1509.2436854839325]
# 0
# Epoch [183/200], Discriminator 0.3917, Best Generator[0] 2.1005
# [1475.8262609243393, 1477.490814089775, 1473.491465330124]
# 0
# Epoch [184/200], Discriminator 0.4709, Best Generator[0] 1.9953
# [1496.7586901187897, 1493.2210052013397, 1490.3050427436829]
# 0
# Epoch [185/200], Discriminator 0.2535, Best Generator[0] 2.5636
# [1501.7618091106415, 1501.7526310682297, 1501.670302271843]
# 1
# Epoch [186/200], Discriminator 0.3574, Best Generator[1] 2.5250
# [1473.310260295868, 1469.4067120552063, 1470.8362765312195]
# 2
# Epoch [187/200], Discriminator 0.4591, Best Generator[2] 2.2765
# [1495.269937157631, 1498.0802828073502, 1496.7297115325928]
# 1
# Epoch [188/200], Discriminator 0.4222, Best Generator[1] 2.2902
# [1478.0921540260315, 1479.7072224617004, 1478.5325223207474]
# 0
# Epoch [189/200], Discriminator 0.3953, Best Generator[0] 3.0106
# [1482.1148406267166, 1484.9895396232605, 1483.89852809906]
# 2
# Epoch [190/200], Discriminator 0.3820, Best Generator[2] 2.4401
# [1492.6789611577988, 1489.3408639431, 1495.1178994178772]
# 2
# Epoch [191/200], Discriminator 0.4837, Best Generator[2] 2.0778
# [1516.0503951311111, 1519.552711725235, 1520.2783445119858]
# 1
# Epoch [192/200], Discriminator 0.4064, Best Generator[1] 2.0950
# [1487.676155090332, 1491.1975754499435, 1493.0370012521744]
# 2
# Epoch [193/200], Discriminator 0.2974, Best Generator[2] 2.7727
# [1480.5652387142181, 1478.4136488437653, 1483.704022526741]
# 2
# Epoch [194/200], Discriminator 0.3899, Best Generator[2] 2.6618
# [1476.3197503089905, 1476.7173880338669, 1476.4959983825684]
# 0
# Epoch [195/200], Discriminator 0.4200, Best Generator[0] 2.3792
# [1479.811439037323, 1479.9537048339844, 1479.7217903137207]
# 2
# Epoch [196/200], Discriminator 0.3073, Best Generator[2] 2.6691
# [1496.1047531366348, 1493.686880350113, 1496.5419181585312]
# 2
# Epoch [197/200], Discriminator 0.3287, Best Generator[2] 2.5075
# [1496.855619430542, 1497.192771077156, 1496.5529420375824]
# 2
# Epoch [198/200], Discriminator 0.4023, Best Generator[2] 1.9094
# [1483.6324620246887, 1486.0738664865494, 1481.0737770795822]
# 1
# Epoch [199/200], Discriminator 0.4029, Best Generator[1] 2.4328
# [1496.4035314321518, 1497.467295408249, 1493.4807671308517]
# 1
# Epoch [200/200], Discriminator 0.3876, Best Generator[1] 2.8800

# %%
# Plot the Loss for Generator and Discriminator
lossManager.drawLossPlot(showPlot = True, savePlot = False)

# %%
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Random Co-Operative GAN')
plt.plot(lossManager.getGeneratorLoss(), label='Generator Loss')
plt.plot(lossManager.getDiscriminatorLoss(), label='Discriminator Loss')
#legend = plt.legend(loc='upper right', shadow=True)
#plt.show()
plt.savefig('Loss_Plot_Vanilla_Random_Co-Operative_GAN_'+str(num_epochs)+'.png')

# %%
#lossManager.drawLossPlot(showPlot = True, savePlot = False, genList = True)

# %%
#lossL = lossManager.getGeneratorsList()
#print lossL

# %%
# Generate GIF
generate_animation(path, num_epochs, 'Random_Multiple_Gens')

# %%
# Save the model
torch.save(Generators[BestPerformingGenerator].state_dict(), './Generator.pkl')
torch.save(Discriminator.state_dict(), './Discriminator.pkl')
pickle.dump(lossManager, open( "LossManager.pkl", "wb" ))

# %%
# Load Loss Manager for viewing data of 200 iterations
#lossManagerTrained = pickle.load(open( "200Iteration/LossManager.pkl", "rb" ))

# %%
#drawLossPlot(lossManagerTrained.getGeneratorLoss(), lossManagerTrained.getDiscriminatorLoss(), showPlot = False, savePlot = True, loc = "200Iteration")
#drawLossPlot(lossManagerTrained.getGeneratorLoss(), lossManagerTrained.getDiscriminatorLoss(), showPlot = True, savePlot = False, loc = "200Iteration")

# %%
# Load model for debugging and testing
#Generator.load_state_dict(torch.load('Generator200.pkl'))
#Discriminator.load_state_dict(torch.load('Discriminator200.pkl'))
